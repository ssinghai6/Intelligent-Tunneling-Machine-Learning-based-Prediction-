# %%
from flask import Flask, request, render_template
from keras.models import load_model
import tensorflow_addons as tfa
import numpy as np
import sklearn as sk
import pandas as pd
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
# Out:
# c:\Users\ssinghai6\A\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.8.0 and strictly below 2.11.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.11.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
def ANN1_Predict(model1,scaler,d_b,density,E,v,phi,psi,c):
    a1 = model1.predict(scaler.transform([[d_b,density,E,v,phi,psi,c]]))
    a1 = np.reshape(a1,-1)
    return a1

# %%
import numpy as np
depth = []
depth[0:50] = np.linspace(3,10,50)
depth[50:100] = np.linspace(10,3,50)
list_Elas = []
list_density = []
list_v =[]
list_phi = []
list_psi =[]
list_c =[]
# d_b_list = [3,5,7,10]
# E_list = [20,35,55,75]
# density_list = [1.6e-09, 2.4e-09]
# v_list = [0.2,0.4]
# phi_list = [20.  , 26.25, 32.5 , 38.75, 45.  ]
# psi_list = [ 2.   ,  6.   , 10.   , 14.   , 18.   ,  2.625,  7.875, 13.125,
#        18.375, 23.625,  3.25 ,  9.75 , 16.25 , 22.75 , 29.25 ,  3.875,
#        11.625, 19.375, 27.125, 34.875,  4.5  , 13.5  , 22.5  , 31.5  ,
#        40.5  ]
# c_list = [0.025375, 0.05025 , 0.075125, 0.1     , 0.0005  ]

elas_mus = [50, 20, 55, 50, 40, 30, 60]
elas_sigmas = [8, 6, 5, 3.5, 3, 2, 1]

density_mus = [2.0e-09,1.80e-09,2.2e-09, 1.90e-09,1.75e-09,2.1e-09,1.6e-09]
density_sigmas = [0.3e-09, 0.25e-09, 0.2e-09, 0.17e-09, 0.15e-09, 0.11e-09, 0.1e-09]

v_mus = [0.24,0.28,0.35,0.3,0.23,0.36,0.25]
v_sigmas = [0.07,0.05,0.04,0.03,0.025,0.022,0.02]

phi_mus = [40,20,27,32,35,28,33]
phi_sigmas = [4,3.5,3,2.5,2,1.5,1]

psi_mus = [20,10,13.5,16,17.5,14,11]
psi_sigmas = [6,4,3,2.5,2,1.5,1]

c_mus = [0.015,0.08,0.018,0.055,0.085,0.05,0.019]
c_sigmas = [0.006,0.004,0.003,0.0025,0.002,0.0015,0.001]


for d_b in depth:
    if d_b >=3 and d_b<4:
        k = 0 
        mu_density,mu_elas,mu_v,mu_phi,mu_psi,mu_c = density_mus[k],elas_mus[k],v_mus[k],phi_mus[k],psi_mus[k],c_mus[k]
        sigma_density, sigma_elas, sigma_v, sigma_phi, sigma_psi, sigma_c = density_sigmas[k],elas_sigmas[k],v_sigmas[k],phi_sigmas[k],psi_sigmas[k],c_sigmas[k]
        
    if d_b >=4 and d_b<5:
        k = 1
        mu_density,mu_elas,mu_v,mu_phi,mu_psi,mu_c = density_mus[k],elas_mus[k],v_mus[k],phi_mus[k],psi_mus[k],c_mus[k]
        sigma_density, sigma_elas, sigma_v, sigma_phi, sigma_psi, sigma_c = density_sigmas[k],elas_sigmas[k],v_sigmas[k],phi_sigmas[k],psi_sigmas[k],c_sigmas[k]
    if d_b >=5 and d_b<6:
        k = 2 
        mu_density,mu_elas,mu_v,mu_phi,mu_psi,mu_c = density_mus[k],elas_mus[k],v_mus[k],phi_mus[k],psi_mus[k],c_mus[k]
        sigma_density, sigma_elas, sigma_v, sigma_phi, sigma_psi, sigma_c = density_sigmas[k],elas_sigmas[k],v_sigmas[k],phi_sigmas[k],psi_sigmas[k],c_sigmas[k]
    if d_b >=6 and d_b<7:
        k = 3 
        mu_density,mu_elas,mu_v,mu_phi,mu_psi,mu_c = density_mus[k],elas_mus[k],v_mus[k],phi_mus[k],psi_mus[k],c_mus[k]
        sigma_density, sigma_elas, sigma_v, sigma_phi, sigma_psi, sigma_c = density_sigmas[k],elas_sigmas[k],v_sigmas[k],phi_sigmas[k],psi_sigmas[k],c_sigmas[k]
        
    if d_b >=7 and d_b<8:
        k = 4 
        mu_density,mu_elas,mu_v,mu_phi,mu_psi,mu_c = density_mus[k],elas_mus[k],v_mus[k],phi_mus[k],psi_mus[k],c_mus[k]
        sigma_density, sigma_elas, sigma_v, sigma_phi, sigma_psi, sigma_c = density_sigmas[k],elas_sigmas[k],v_sigmas[k],phi_sigmas[k],psi_sigmas[k],c_sigmas[k]
        
    if d_b >=8 and d_b<9:k = 0 
        k = 5
        mu_density,mu_elas,mu_v,mu_phi,mu_psi,mu_c = density_mus[k],elas_mus[k],v_mus[k],phi_mus[k],psi_mus[k],c_mus[k]
        sigma_density, sigma_elas, sigma_v, sigma_phi, sigma_psi, sigma_c = density_sigmas[k],elas_sigmas[k],v_sigmas[k],phi_sigmas[k],psi_sigmas[k],c_sigmas[k]
        
    if d_b >=9 and d_b<10:
        k = 6 
        mu_density,mu_elas,mu_v,mu_phi,mu_psi,mu_c = density_mus[k],elas_mus[k],v_mus[k],phi_mus[k],psi_mus[k],c_mus[k]
        sigma_density, sigma_elas, sigma_v, sigma_phi, sigma_psi, sigma_c = density_sigmas[k],elas_sigmas[k],v_sigmas[k],phi_sigmas[k],psi_sigmas[k],c_sigmas[k]
        
    list_Elas.append(np.random.normal(mu_elas, sigma_elas))
    list_density.append(np.random.normal(mu_density, sigma_density))
    list_v.append(np.random.normal(mu_v, sigma_v))
    list_phi.append(np.random.normal(mu_phi, sigma_phi))
    list_psi.append(np.random.normal(mu_psi, sigma_psi))
    list_c.append(np.random.normal(mu_c, sigma_c))
# Out:
#   Input In [66]
#     k = 5
#     ^
# IndentationError: unexpected indent

# %%
np.min(list_Elas)
# Out:
# 13.907946596655517

# %%
# Generate plots
mu_density, mu_elas, mu_v, mu_phi, mu_psi, mu_c = mu_list[d_index], mu_list[d_index+1], mu_list[d_index+2], mu_list[d_index+3], mu_list[d_index+4], mu_list[d_index+5]
sigma_density, sigma_elas, sigma_v, sigma_phi, sigma_psi, sigma_c = sigma_list[d_index], sigma_list[d_index+1], sigma_list[d_index+2], sigma_list[d_index+3], sigma_list[d_index+4], sigma_list[d_index+5]

for i in range(6):
    fig, ax = plt.subplots()
    for j, d_b in enumerate(depth):
        if i == 0:
            label = f"d_b = {d_b} m"
            mu, sigma = mu_density[j], sigma_density[j]
        elif i == 1:
            label = f"d_b = {d_b} m"
            mu, sigma = mu_elas[j], sigma_elas[j]
        elif i == 2:
            label = f"d_b = {d_b} m"
            mu, sigma = mu_v[j], sigma_v[j]
        elif i == 3:
            label = f"d_b = {d_b} m"
            mu, sigma = mu_phi[j], sigma_phi[j]
        elif i == 4:
            label = f"d_b = {d_b} m"
            mu, sigma = mu_psi[j], sigma_psi[j]
        elif i == 5:
            label = f"d_b = {d_b} m"
            mu, sigma = mu_c[j], sigma_c[j]
        
        x = np.linspace(mu - 4*sigma, mu + 4*sigma, 100)
        ax.plot(x, norm.pdf(x, mu, sigma), label=label)

    ax.set_xlabel('Value')
    ax.set_ylabel('Probability density')
    ax.set_title(f'Normal distribution plot for {properties[i]}')
    ax.legend()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Sanshrit\VIP\Archive\RNN_parametrized_Pdistri_Reverse.ipynb Cell 5 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Sanshrit/VIP/Archive/RNN_parametrized_Pdistri_Reverse.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> # Generate plots
# ----> <a href='vscode-notebook-cell:/d%3A/Sanshrit/VIP/Archive/RNN_parametrized_Pdistri_Reverse.ipynb#X33sZmlsZQ%3D%3D?line=1'>2</a> mu_density, mu_elas, mu_v, mu_phi, mu_psi, mu_c = mu_list[d_index], mu_list[d_index+1], mu_list[d_index+2], mu_list[d_index+3], mu_list[d_index+4], mu_list[d_index+5]
#       <a href='vscode-notebook-cell:/d%3A/Sanshrit/VIP/Archive/RNN_parametrized_Pdistri_Reverse.ipynb#X33sZmlsZQ%3D%3D?line=2'>3</a> sigma_density, sigma_elas, sigma_v, sigma_phi, sigma_psi, sigma_c = sigma_list[d_index], sigma_list[d_index+1], sigma_list[d_index+2], sigma_list[d_index+3], sigma_list[d_index+4], sigma_list[d_index+5]
#       <a href='vscode-notebook-cell:/d%3A/Sanshrit/VIP/Archive/RNN_parametrized_Pdistri_Reverse.ipynb#X33sZmlsZQ%3D%3D?line=4'>5</a> for i in range(6):
#
# NameError: name 'mu_list' is not defined

# %%
list_Elas
# Out:
# [50.538814015633335,
#  47.16118134756585,
#  50.01752357054197,
#  24.59015458134536,
#  19.52243033553948,
#  23.22235056106411,
#  42.90094904334483,
#  72.63328264457026,
#  46.38383405737117,
#  47.625021710310996,
#  47.93371605244107,
#  45.4202148162079,
#  36.84552503234196,
#  40.912517682914014,
#  23.044870048239666,
#  26.501877331153292,
#  28.676621875004766,
#  69.5696247790699,
#  47.031944358426735,
#  61.85719395700952,
#  50.89556791694773,
#  56.37378263649791,
#  56.99084103527797,
#  32.0565860569252,
#  29.66279350512137,
#  34.054329318505125,
#  44.72284713753991,
#  40.73710162662248,
#  32.76099443999587,
#  55.96423159747492,
#  48.63306095328769,
#  62.94342250601643,
#  56.01678396111545,
#  55.360293933849825,
#  17.757775913037094,
#  15.575017915800576,
#  17.06575810719709,
#  41.64650288257947,
#  49.535964031925786,
#  50.47996311308711]

# %%
import numpy as np
import matplotlib.pyplot as plt

mu_elas = [60, 30, 75, 25, 50]
sigma_elas = [5, 3, 20, 10, 15]

mu_density = [ 2.0e-09,  1.8e-09,  2.2e-09,  1.90e-09, 2.1e-09]
sigma_density = [ 0.2e-09,  0.3e-09,  0.1e-09,  0.15e-09, 0.2e-09]

mu_v = [0.3, 0.2, 0.35, 0.3, 0.32]
sigma_v = [0.1, 0.12, 0.05, 0.07, 0.04]

mu_phi = [30, 20, 27, 32, 35]
sigma_phi = [1, 2, 4, 2, 2]

mu_psi = [9,15,18,23,21]
sigma_psi = [2,2,3,1,2]

mu_c = [0.05, 0.006, 0.008, 0.055, 0.003]
sigma_c = [0.0002, 0.0001, 0.0003, 0.0004, 0.00035]

fig, axs = plt.subplots(2, 3, figsize=(12, 8))
axs = axs.flatten()

for i in range(6):
    if i == 0:
        mu = mu_elas
        sigma = sigma_elas
        x_label = 'Elastic Modulus'
    elif i == 1:
        mu = mu_density
        sigma = sigma_density
        x_label = 'Density'
    elif i == 2:
        mu = mu_v
        sigma = sigma_v
        x_label = 'V'
    elif i == 3:
        mu = mu_phi
        sigma = sigma_phi
        x_label = 'Phi'
    elif i == 4:
        mu = mu_psi
        sigma = sigma_psi
        x_label = 'Psi'
    else:
        mu = mu_c
        sigma = sigma_c
        x_label = 'C'
    
    for j in range(5):
        x = np.random.normal(mu[j], sigma[j], size=1000)
        axs[i].hist(x, bins=30, density=True, alpha=0.5, label=f'Case {j+1}')
        axs[i].set_xlabel(x_label)
        axs[i].set_ylabel('Probability Density')
        axs[i].set_xlim(mu[j]-2*sigma[j], mu[j]+2*sigma[j])
        axs[i].legend()

plt.tight_layout()
plt.show()

# %%
# Generate plots
for i in range(6):
    fig, ax = plt.subplots()
    for j, d_b in enumerate(depth):
        if i == 0:
            label = f"d_b = {d_b} m"
            mu, sigma = mu_density[j], sigma_density[j]
        elif i == 1:
            label = f"d_b = {d_b} m"
            mu, sigma = mu_elas[j], sigma_elas[j]
        elif i == 2:
            label = f"d_b = {d_b} m"
            mu, sigma = mu_v[j], sigma_v[j]
        elif i == 3:
            label = f"d_b = {d_b} m"
            mu, sigma = mu_phi[j], sigma_phi[j]
        elif i == 4:
            label = f"d_b = {d_b} m"
            mu, sigma = mu_psi[j], sigma_psi[j]
        elif i == 5:
            label = f"d_b = {d_b} m"
            mu, sigma = mu_c[j], sigma_c[j]
        
        x = np.linspace(mu - 4*sigma, mu + 4*sigma, 100)
        ax.plot(x, norm.pdf(x, mu, sigma), label=label)

    ax.set_xlabel('Value')
    ax.set_ylabel('Probability density')
    ax.set_title(f'Normal distribution plot for {properties[i]}')
    ax.legend()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Sanshrit\VIP\Archive\RNN_parametrized_Pdistri_Reverse.ipynb Cell 8 in <cell line: 2>()
#      <a href='vscode-notebook-cell:/d%3A/Sanshrit/VIP/Archive/RNN_parametrized_Pdistri_Reverse.ipynb#X41sZmlsZQ%3D%3D?line=21'>22</a>         mu, sigma = mu_c[j], sigma_c[j]
#      <a href='vscode-notebook-cell:/d%3A/Sanshrit/VIP/Archive/RNN_parametrized_Pdistri_Reverse.ipynb#X41sZmlsZQ%3D%3D?line=23'>24</a>     x = np.linspace(mu - 4*sigma, mu + 4*sigma, 100)
# ---> <a href='vscode-notebook-cell:/d%3A/Sanshrit/VIP/Archive/RNN_parametrized_Pdistri_Reverse.ipynb#X41sZmlsZQ%3D%3D?line=24'>25</a>     ax.plot(x, norm.pdf(x, mu, sigma), label=label)
#      <a href='vscode-notebook-cell:/d%3A/Sanshrit/VIP/Archive/RNN_parametrized_Pdistri_Reverse.ipynb#X41sZmlsZQ%3D%3D?line=26'>27</a> ax.set_xlabel('Value')
#      <a href='vscode-notebook-cell:/d%3A/Sanshrit/VIP/Archive/RNN_parametrized_Pdistri_Reverse.ipynb#X41sZmlsZQ%3D%3D?line=27'>28</a> ax.set_ylabel('Probability density')
#
# NameError: name 'norm' is not defined

# %%
import numpy as np
#d_b_list = arr[:,0]
#E_list = arr[:,1]
d_b_list = depth
E_list = list_Elas
density_list = list_density
v_list = list_v
phi_list = list_phi
psi_list = list_psi
c_list = list_c
ANN1 = 'Final_ANN1.h5'
model1 = load_model(ANN1,custom_objects={'RSquare' : tfa.metrics.RSquare})
scaler = pd.read_pickle('scale_ann1.pkl')

# %%
np.shape(list_Elas)
# Out:
# (100,)

# %%
result = []
para = []
paras = []
no = 100
for i in range(no):
    #d_b,density,E,v,phi,psi,c = d_b_list[i],np.random.choice(density_list),E_list[i],np.random.choice(v_list),np.random.choice(phi_list),np.random.choice(psi_list),np.random.choice(c_list)
    d_b,density,E,v,phi,psi,c = d_b_list[i],density_list[i],E_list[i],v_list[i],phi_list[i],psi_list[i],c_list[i]
    temp1 = [density,E,v,phi,psi,c]
    temp = [d_b,density,E,v,phi,psi,c]
    paras.append(temp1)
    para.append(temp)
    res_temp = ANN1_Predict(model1,scaler,d_b,density,E,v,phi,psi,c)
    result.append(res_temp)
# Out:
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step

# %%
np.shape(paras)
# Out:
# (100, 6)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create x-axis values
x = np.arange(no)
para1 = np.reshape(para,(no,7))
# Generate some random y values
para_d_b = para1[:,0]
para_density = para1[:,1]
para_elastic = para1[:,2]
para_v = para1[:,3]
para_phi = para1[:,4]
para_psi = para1[:,5]
para_c = para1[:,6]

# Create a figure with three subplots
fig, axs = plt.subplots(nrows=7, ncols=1, figsize=(8, 8))

# Plot each line in a separate subplot
axs[0].plot(x,para_d_b )
axs[0].set_title('d_b')
axs[1].plot(x, para_density)
axs[1].set_title('Density')
axs[2].plot(x, para_elastic)
axs[2].set_title('Elastic Modulus')
axs[3].plot(x, para_v)
axs[3].set_title('v')
axs[4].plot(x, para_phi)
axs[4].set_title('phi')
axs[5].plot(x, para_psi)
axs[5].set_title('psi')
axs[6].plot(x, para_c)
axs[6].set_title('c')

# Add x and y axis labels
for ax in axs:
    ax.set_xlabel('Time Step')
    ax.set_ylabel('Properties')

# Add some space between the subplots
fig.tight_layout()

# Display the plot
plt.show()

# %%
np.shape(para1)
# Out:
# (100, 7)

# %%
import numpy as np
import pandas as pd
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Load the data into a NumPy array 

# Convert the NumPy array to a Pandas DataFrame
df11 = pd.DataFrame(paras, columns=['desnity', 'elastic modulus', 'v','phi','psi','c'])

# Compute the ACF and PACF for each variable in the data
for col in df11.columns:
    plot_acf(df11[col])
    plot_pacf(df11[col])
# Out:
# c:\Users\ssinghai6\A\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(
# c:\Users\ssinghai6\A\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(
# c:\Users\ssinghai6\A\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(
# c:\Users\ssinghai6\A\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(
# c:\Users\ssinghai6\A\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(
# c:\Users\ssinghai6\A\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, LSTM, GRU
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import tensorflow_addons as tfa

# Define the number of input parameters and time steps
num_inputs = 6
time_steps = 3
# Generate some random data for demonstration purposes
data = paras

# Normalize the data
scaler = StandardScaler()
data = scaler.fit_transform(data)

# Create the training data using a sliding window approach
X_train = []
y_train = []
for i in range(time_steps, len(data)):
    X_train.append(data[i-time_steps:i, :])
    y_train.append(data[i, :])

X_train = np.array(X_train)
y_train = np.array(y_train)

# Reshape the input data to be 3-dimensional in the form (samples, time steps, features)
X_train = np.reshape(X_train, (X_train.shape[0], time_steps, num_inputs))

# Define the LSTM model
model = Sequential()
model.add(GRU(512, input_shape=(time_steps, num_inputs), return_sequences=True))
model.add(GRU(512, activation="relu", return_sequences=True))
model.add(GRU(256, activation="relu"))
model.add(Dense(num_inputs))
metric = tfa.metrics.r_square.RSquare()
model.compile(optimizer='adam', loss='mse', metrics=[metric], run_eagerly=True)

# Train the model
model.fit(X_train, y_train, epochs=200, batch_size=16)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 1s 243ms/step - loss: 0.9578 - r_square: 0.0087
# Epoch 2/200
# 4/4 [==============================] - 1s 240ms/step - loss: 0.8689 - r_square: 0.1013
# Epoch 3/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.7914 - r_square: 0.1809
# Epoch 4/200
# 4/4 [==============================] - 1s 243ms/step - loss: 0.7547 - r_square: 0.2181
# Epoch 5/200
# 4/4 [==============================] - 1s 242ms/step - loss: 0.6935 - r_square: 0.2807
# Epoch 6/200
# 4/4 [==============================] - 1s 248ms/step - loss: 0.6499 - r_square: 0.3255
# Epoch 7/200
# 4/4 [==============================] - 1s 241ms/step - loss: 0.6055 - r_square: 0.3711
# Epoch 8/200
# 4/4 [==============================] - 1s 235ms/step - loss: 0.5586 - r_square: 0.4191
# Epoch 9/200
# 4/4 [==============================] - 1s 236ms/step - loss: 0.5137 - r_square: 0.4666
# Epoch 10/200
# 4/4 [==============================] - 1s 248ms/step - loss: 0.5328 - r_square: 0.4468
# Epoch 11/200
# 4/4 [==============================] - 1s 236ms/step - loss: 0.4781 - r_square: 0.5024
# Epoch 12/200
# 4/4 [==============================] - 1s 235ms/step - loss: 0.4521 - r_square: 0.5306
# Epoch 13/200
# 4/4 [==============================] - 1s 240ms/step - loss: 0.4378 - r_square: 0.5452
# Epoch 14/200
# 4/4 [==============================] - 1s 253ms/step - loss: 0.3994 - r_square: 0.5857
# Epoch 15/200
# 4/4 [==============================] - 1s 248ms/step - loss: 0.3754 - r_square: 0.6103
# Epoch 16/200
# 4/4 [==============================] - 1s 237ms/step - loss: 0.3589 - r_square: 0.6276
# Epoch 17/200
# 4/4 [==============================] - 1s 241ms/step - loss: 0.3103 - r_square: 0.6775
# Epoch 18/200
# 4/4 [==============================] - 1s 235ms/step - loss: 0.2976 - r_square: 0.6916
# Epoch 19/200
# 4/4 [==============================] - 1s 246ms/step - loss: 0.2669 - r_square: 0.7235
# Epoch 20/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.2625 - r_square: 0.7276
# Epoch 21/200
# 4/4 [==============================] - 1s 243ms/step - loss: 0.2274 - r_square: 0.7638
# Epoch 22/200
# 4/4 [==============================] - 1s 230ms/step - loss: 0.2327 - r_square: 0.7572
# Epoch 23/200
# 4/4 [==============================] - 1s 237ms/step - loss: 0.2118 - r_square: 0.7801
# Epoch 24/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.2004 - r_square: 0.7920
# Epoch 25/200
# 4/4 [==============================] - 1s 256ms/step - loss: 0.1704 - r_square: 0.8229
# Epoch 26/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.1509 - r_square: 0.8434
# Epoch 27/200
# 4/4 [==============================] - 1s 234ms/step - loss: 0.1423 - r_square: 0.8529
# Epoch 28/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.1319 - r_square: 0.8631
# Epoch 29/200
# 4/4 [==============================] - 1s 250ms/step - loss: 0.1292 - r_square: 0.8659
# Epoch 30/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.1364 - r_square: 0.8591
# Epoch 31/200
# 4/4 [==============================] - 1s 235ms/step - loss: 0.1158 - r_square: 0.8797
# Epoch 32/200
# 4/4 [==============================] - 1s 236ms/step - loss: 0.1080 - r_square: 0.8876
# Epoch 33/200
# 4/4 [==============================] - 1s 246ms/step - loss: 0.0978 - r_square: 0.8980
# Epoch 34/200
# 4/4 [==============================] - 1s 241ms/step - loss: 0.0879 - r_square: 0.9086
# Epoch 35/200
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0755 - r_square: 0.9213
# Epoch 36/200
# 4/4 [==============================] - 1s 241ms/step - loss: 0.0721 - r_square: 0.9246
# Epoch 37/200
# 4/4 [==============================] - 1s 233ms/step - loss: 0.0661 - r_square: 0.9309
# Epoch 38/200
# 4/4 [==============================] - 1s 235ms/step - loss: 0.0589 - r_square: 0.9383
# Epoch 39/200
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0577 - r_square: 0.9395
# Epoch 40/200
# 4/4 [==============================] - 1s 237ms/step - loss: 0.0474 - r_square: 0.9504
# Epoch 41/200
# 4/4 [==============================] - 1s 238ms/step - loss: 0.0533 - r_square: 0.9442
# Epoch 42/200
# 4/4 [==============================] - 1s 234ms/step - loss: 0.0436 - r_square: 0.9542
# Epoch 43/200
# 4/4 [==============================] - 1s 244ms/step - loss: 0.0431 - r_square: 0.9549
# Epoch 44/200
# 4/4 [==============================] - 1s 251ms/step - loss: 0.0417 - r_square: 0.9564
# Epoch 45/200
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0405 - r_square: 0.9578
# Epoch 46/200
# 4/4 [==============================] - 1s 233ms/step - loss: 0.0379 - r_square: 0.9601
# Epoch 47/200
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0371 - r_square: 0.9611
# Epoch 48/200
# 4/4 [==============================] - 1s 248ms/step - loss: 0.0317 - r_square: 0.9664
# Epoch 49/200
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0268 - r_square: 0.9719
# Epoch 50/200
# 4/4 [==============================] - 1s 235ms/step - loss: 0.0265 - r_square: 0.9719
# Epoch 51/200
# 4/4 [==============================] - 1s 241ms/step - loss: 0.0225 - r_square: 0.9761
# Epoch 52/200
# 4/4 [==============================] - 1s 249ms/step - loss: 0.0178 - r_square: 0.9811
# Epoch 53/200
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0170 - r_square: 0.9819
# Epoch 54/200
# 4/4 [==============================] - 1s 245ms/step - loss: 0.0153 - r_square: 0.9837
# Epoch 55/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.0178 - r_square: 0.9811
# Epoch 56/200
# 4/4 [==============================] - 1s 237ms/step - loss: 0.0139 - r_square: 0.9852
# Epoch 57/200
# 4/4 [==============================] - 1s 243ms/step - loss: 0.0141 - r_square: 0.9851
# Epoch 58/200
# 4/4 [==============================] - 1s 249ms/step - loss: 0.0100 - r_square: 0.9894
# Epoch 59/200
# 4/4 [==============================] - 1s 238ms/step - loss: 0.0125 - r_square: 0.9868
# Epoch 60/200
# 4/4 [==============================] - 1s 234ms/step - loss: 0.0124 - r_square: 0.9870
# Epoch 61/200
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0126 - r_square: 0.9869
# Epoch 62/200
# 4/4 [==============================] - 1s 246ms/step - loss: 0.0174 - r_square: 0.9820
# Epoch 63/200
# 4/4 [==============================] - 1s 246ms/step - loss: 0.0168 - r_square: 0.9827
# Epoch 64/200
# 4/4 [==============================] - 1s 234ms/step - loss: 0.0165 - r_square: 0.9829
# Epoch 65/200
# 4/4 [==============================] - 1s 237ms/step - loss: 0.0144 - r_square: 0.9852
# Epoch 66/200
# 4/4 [==============================] - 1s 234ms/step - loss: 0.0121 - r_square: 0.9874
# Epoch 67/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.0122 - r_square: 0.9873
# Epoch 68/200
# 4/4 [==============================] - 1s 238ms/step - loss: 0.0114 - r_square: 0.9880
# Epoch 69/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.0117 - r_square: 0.9878
# Epoch 70/200
# 4/4 [==============================] - 1s 234ms/step - loss: 0.0110 - r_square: 0.9886
# Epoch 71/200
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0098 - r_square: 0.9897
# Epoch 72/200
# 4/4 [==============================] - 1s 243ms/step - loss: 0.0083 - r_square: 0.9913
# Epoch 73/200
# 4/4 [==============================] - 1s 248ms/step - loss: 0.0096 - r_square: 0.9901
# Epoch 74/200
# 4/4 [==============================] - 1s 242ms/step - loss: 0.0097 - r_square: 0.9899
# Epoch 75/200
# 4/4 [==============================] - 1s 237ms/step - loss: 0.0070 - r_square: 0.9927
# Epoch 76/200
# 4/4 [==============================] - 1s 238ms/step - loss: 0.0064 - r_square: 0.9933
# Epoch 77/200
# 4/4 [==============================] - 1s 247ms/step - loss: 0.0063 - r_square: 0.9934
# Epoch 78/200
# 4/4 [==============================] - 1s 245ms/step - loss: 0.0049 - r_square: 0.9949
# Epoch 79/200
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0061 - r_square: 0.9937
# Epoch 80/200
# 4/4 [==============================] - 1s 235ms/step - loss: 0.0046 - r_square: 0.9951
# Epoch 81/200
# 4/4 [==============================] - 1s 243ms/step - loss: 0.0040 - r_square: 0.9958
# Epoch 82/200
# 4/4 [==============================] - 1s 237ms/step - loss: 0.0043 - r_square: 0.9955
# Epoch 83/200
# 4/4 [==============================] - 1s 245ms/step - loss: 0.0034 - r_square: 0.9963
# Epoch 84/200
# 4/4 [==============================] - 1s 246ms/step - loss: 0.0041 - r_square: 0.9957
# Epoch 85/200
# 4/4 [==============================] - 1s 235ms/step - loss: 0.0033 - r_square: 0.9965
# Epoch 86/200
# 4/4 [==============================] - 1s 242ms/step - loss: 0.0034 - r_square: 0.9964
# Epoch 87/200
# 4/4 [==============================] - 1s 246ms/step - loss: 0.0029 - r_square: 0.9969
# Epoch 88/200
# 4/4 [==============================] - 1s 237ms/step - loss: 0.0027 - r_square: 0.9971
# Epoch 89/200
# 4/4 [==============================] - 1s 235ms/step - loss: 0.0040 - r_square: 0.9957
# Epoch 90/200
# 4/4 [==============================] - 1s 241ms/step - loss: 0.0041 - r_square: 0.9957
# Epoch 91/200
# 4/4 [==============================] - 1s 244ms/step - loss: 0.0056 - r_square: 0.9941
# Epoch 92/200
# 4/4 [==============================] - 1s 257ms/step - loss: 0.0059 - r_square: 0.9938
# Epoch 93/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.0047 - r_square: 0.9951
# Epoch 94/200
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0059 - r_square: 0.9938
# Epoch 95/200
# 4/4 [==============================] - 1s 233ms/step - loss: 0.0062 - r_square: 0.9935
# Epoch 96/200
# 4/4 [==============================] - 1s 249ms/step - loss: 0.0048 - r_square: 0.9950
# Epoch 97/200
# 4/4 [==============================] - 1s 237ms/step - loss: 0.0048 - r_square: 0.9950
# Epoch 98/200
# 4/4 [==============================] - 1s 241ms/step - loss: 0.0043 - r_square: 0.9956
# Epoch 99/200
# 4/4 [==============================] - 1s 237ms/step - loss: 0.0038 - r_square: 0.9961
# Epoch 100/200
# 4/4 [==============================] - 1s 242ms/step - loss: 0.0043 - r_square: 0.9955
# Epoch 101/200
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0039 - r_square: 0.9960
# Epoch 102/200
# 4/4 [==============================] - 1s 248ms/step - loss: 0.0036 - r_square: 0.9963
# Epoch 103/200
# 4/4 [==============================] - 1s 246ms/step - loss: 0.0038 - r_square: 0.9960
# Epoch 104/200
# 4/4 [==============================] - 1s 238ms/step - loss: 0.0034 - r_square: 0.9965
# Epoch 105/200
# 4/4 [==============================] - 1s 237ms/step - loss: 0.0033 - r_square: 0.9966
# Epoch 106/200
# 4/4 [==============================] - 1s 254ms/step - loss: 0.0030 - r_square: 0.9969
# Epoch 107/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.0030 - r_square: 0.9969
# Epoch 108/200
# 4/4 [==============================] - 1s 231ms/step - loss: 0.0023 - r_square: 0.9976
# Epoch 109/200
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0025 - r_square: 0.9974
# Epoch 110/200
# 4/4 [==============================] - 1s 245ms/step - loss: 0.0028 - r_square: 0.9971
# Epoch 111/200
# 4/4 [==============================] - 1s 244ms/step - loss: 0.0019 - r_square: 0.9980
# Epoch 112/200
# 4/4 [==============================] - 1s 240ms/step - loss: 0.0020 - r_square: 0.9979
# Epoch 113/200
# 4/4 [==============================] - 1s 240ms/step - loss: 0.0022 - r_square: 0.9977
# Epoch 114/200
# 4/4 [==============================] - 1s 241ms/step - loss: 0.0017 - r_square: 0.9983
# Epoch 115/200
# 4/4 [==============================] - 1s 245ms/step - loss: 0.0022 - r_square: 0.9976
# Epoch 116/200
# 4/4 [==============================] - 1s 242ms/step - loss: 0.0014 - r_square: 0.9985
# Epoch 117/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.0018 - r_square: 0.9981
# Epoch 118/200
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0015 - r_square: 0.9984
# Epoch 119/200
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0014 - r_square: 0.9985
# Epoch 120/200
# 4/4 [==============================] - 1s 242ms/step - loss: 0.0016 - r_square: 0.9983
# Epoch 121/200
# 4/4 [==============================] - 1s 252ms/step - loss: 0.0016 - r_square: 0.9983
# Epoch 122/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.0014 - r_square: 0.9986
# Epoch 123/200
# 4/4 [==============================] - 1s 234ms/step - loss: 0.0013 - r_square: 0.9986
# Epoch 124/200
# 4/4 [==============================] - 1s 234ms/step - loss: 0.0014 - r_square: 0.9985
# Epoch 125/200
# 4/4 [==============================] - 1s 246ms/step - loss: 0.0016 - r_square: 0.9983
# Epoch 126/200
# 4/4 [==============================] - 1s 229ms/step - loss: 0.0016 - r_square: 0.9982
# Epoch 127/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.0010 - r_square: 0.9989
# Epoch 128/200
# 4/4 [==============================] - 1s 235ms/step - loss: 9.4358e-04 - r_square: 0.9990
# Epoch 129/200
# 4/4 [==============================] - 1s 257ms/step - loss: 0.0019 - r_square: 0.9980
# Epoch 130/200
# 4/4 [==============================] - 1s 241ms/step - loss: 0.0018 - r_square: 0.9981
# Epoch 131/200
# 4/4 [==============================] - 1s 238ms/step - loss: 0.0021 - r_square: 0.9977
# Epoch 132/200
# 4/4 [==============================] - 1s 242ms/step - loss: 0.0021 - r_square: 0.9977
# Epoch 133/200
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0027 - r_square: 0.9970
# Epoch 134/200
# 4/4 [==============================] - 1s 235ms/step - loss: 0.0033 - r_square: 0.9965
# Epoch 135/200
# 4/4 [==============================] - 1s 244ms/step - loss: 0.0041 - r_square: 0.9957
# Epoch 136/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.0040 - r_square: 0.9958
# Epoch 137/200
# 4/4 [==============================] - 1s 234ms/step - loss: 0.0035 - r_square: 0.9963
# Epoch 138/200
# 4/4 [==============================] - 1s 237ms/step - loss: 0.0037 - r_square: 0.9961
# Epoch 139/200
# 4/4 [==============================] - 1s 250ms/step - loss: 0.0037 - r_square: 0.9961
# Epoch 140/200
# 4/4 [==============================] - 1s 254ms/step - loss: 0.0035 - r_square: 0.9962
# Epoch 141/200
# 4/4 [==============================] - 1s 240ms/step - loss: 0.0054 - r_square: 0.9943
# Epoch 142/200
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0040 - r_square: 0.9958
# Epoch 143/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.0047 - r_square: 0.9950
# Epoch 144/200
# 4/4 [==============================] - 1s 254ms/step - loss: 0.0047 - r_square: 0.9951
# Epoch 145/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.0071 - r_square: 0.9927
# Epoch 146/200
# 4/4 [==============================] - 1s 240ms/step - loss: 0.0070 - r_square: 0.9927
# Epoch 147/200
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0061 - r_square: 0.9937
# Epoch 148/200
# 4/4 [==============================] - 1s 246ms/step - loss: 0.0060 - r_square: 0.9939
# Epoch 149/200
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0061 - r_square: 0.9936
# Epoch 150/200
# 4/4 [==============================] - 1s 248ms/step - loss: 0.0054 - r_square: 0.9943
# Epoch 151/200
# 4/4 [==============================] - 1s 238ms/step - loss: 0.0044 - r_square: 0.9955
# Epoch 152/200
# 4/4 [==============================] - 1s 235ms/step - loss: 0.0062 - r_square: 0.9935
# Epoch 153/200
# 4/4 [==============================] - 1s 243ms/step - loss: 0.0050 - r_square: 0.9948
# Epoch 154/200
# 4/4 [==============================] - 1s 245ms/step - loss: 0.0069 - r_square: 0.9930
# Epoch 155/200
# 4/4 [==============================] - 1s 240ms/step - loss: 0.0065 - r_square: 0.9933
# Epoch 156/200
# 4/4 [==============================] - 1s 233ms/step - loss: 0.0067 - r_square: 0.9931
# Epoch 157/200
# 4/4 [==============================] - 1s 235ms/step - loss: 0.0049 - r_square: 0.9949
# Epoch 158/200
# 4/4 [==============================] - 1s 248ms/step - loss: 0.0084 - r_square: 0.9913
# Epoch 159/200
# 4/4 [==============================] - 1s 258ms/step - loss: 0.0050 - r_square: 0.9948
# Epoch 160/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.0060 - r_square: 0.9938
# Epoch 161/200
# 4/4 [==============================] - 1s 235ms/step - loss: 0.0071 - r_square: 0.9926
# Epoch 162/200
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0062 - r_square: 0.9935
# Epoch 163/200
# 4/4 [==============================] - 1s 243ms/step - loss: 0.0051 - r_square: 0.9947
# Epoch 164/200
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0044 - r_square: 0.9955
# Epoch 165/200
# 4/4 [==============================] - 1s 241ms/step - loss: 0.0034 - r_square: 0.9964
# Epoch 166/200
# 4/4 [==============================] - 1s 234ms/step - loss: 0.0041 - r_square: 0.9958
# Epoch 167/200
# 4/4 [==============================] - 1s 245ms/step - loss: 0.0048 - r_square: 0.9950
# Epoch 168/200
# 4/4 [==============================] - 1s 241ms/step - loss: 0.0033 - r_square: 0.9966
# Epoch 169/200
# 4/4 [==============================] - 1s 259ms/step - loss: 0.0024 - r_square: 0.9975
# Epoch 170/200
# 4/4 [==============================] - 1s 240ms/step - loss: 0.0094 - r_square: 0.9906
# Epoch 171/200
# 4/4 [==============================] - 1s 235ms/step - loss: 0.0094 - r_square: 0.9905
# Epoch 172/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.0064 - r_square: 0.9936
# Epoch 173/200
# 4/4 [==============================] - 1s 257ms/step - loss: 0.0064 - r_square: 0.9935
# Epoch 174/200
# 4/4 [==============================] - 1s 243ms/step - loss: 0.0052 - r_square: 0.9947
# Epoch 175/200
# 4/4 [==============================] - 1s 241ms/step - loss: 0.0037 - r_square: 0.9962
# Epoch 176/200
# 4/4 [==============================] - 1s 245ms/step - loss: 0.0065 - r_square: 0.9933
# Epoch 177/200
# 4/4 [==============================] - 1s 255ms/step - loss: 0.0072 - r_square: 0.9925
# Epoch 178/200
# 4/4 [==============================] - 1s 249ms/step - loss: 0.0067 - r_square: 0.9930
# Epoch 179/200
# 4/4 [==============================] - 1s 240ms/step - loss: 0.0063 - r_square: 0.9934
# Epoch 180/200
# 4/4 [==============================] - 1s 242ms/step - loss: 0.0055 - r_square: 0.9942
# Epoch 181/200
# 4/4 [==============================] - 1s 237ms/step - loss: 0.0040 - r_square: 0.9958
# Epoch 182/200
# 4/4 [==============================] - 1s 244ms/step - loss: 0.0039 - r_square: 0.9959
# Epoch 183/200
# 4/4 [==============================] - 1s 247ms/step - loss: 0.0033 - r_square: 0.9965
# Epoch 184/200
# 4/4 [==============================] - 1s 242ms/step - loss: 0.0060 - r_square: 0.9937
# Epoch 185/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.0045 - r_square: 0.9952
# Epoch 186/200
# 4/4 [==============================] - 1s 245ms/step - loss: 0.0039 - r_square: 0.9957
# Epoch 187/200
# 4/4 [==============================] - 1s 246ms/step - loss: 0.0039 - r_square: 0.9958
# Epoch 188/200
# 4/4 [==============================] - 1s 250ms/step - loss: 0.0035 - r_square: 0.9962
# Epoch 189/200
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0023 - r_square: 0.9975
# Epoch 190/200
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0023 - r_square: 0.9976
# Epoch 191/200
# 4/4 [==============================] - 1s 233ms/step - loss: 0.0021 - r_square: 0.9978
# Epoch 192/200
# 4/4 [==============================] - 1s 237ms/step - loss: 0.0018 - r_square: 0.9981
# Epoch 193/200
# 4/4 [==============================] - 1s 236ms/step - loss: 0.0021 - r_square: 0.9977
# Epoch 194/200
# 4/4 [==============================] - 1s 235ms/step - loss: 0.0023 - r_square: 0.9976
# Epoch 195/200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Sanshrit\VIP\Archive\RNN_parametrized_Pdistri_Reverse.ipynb Cell 16 in <cell line: 40>()
#      <a href='vscode-notebook-cell:/d%3A/Sanshrit/VIP/Archive/RNN_parametrized_Pdistri_Reverse.ipynb#X21sZmlsZQ%3D%3D?line=36'>37</a> model.compile(optimizer='adam', loss='mse', metrics=[metric], run_eagerly=True)
#      <a href='vscode-notebook-cell:/d%3A/Sanshrit/VIP/Archive/RNN_parametrized_Pdistri_Reverse.ipynb#X21sZmlsZQ%3D%3D?line=38'>39</a> # Train the model
# ---> <a href='vscode-notebook-cell:/d%3A/Sanshrit/VIP/Archive/RNN_parametrized_Pdistri_Reverse.ipynb#X21sZmlsZQ%3D%3D?line=39'>40</a> model.fit(X_train, y_train, epochs=200, batch_size=16)
#
# File c:\Users\ssinghai6\A\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ssinghai6\A\lib\site-packages\keras\engine\training.py:1650, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1642 with tf.profiler.experimental.Trace(
#    1643     "train",
#    1644     epoch_num=epoch,
#    (...)
#    1647     _r=1,
#    1648 ):
#    1649     callbacks.on_train_batch_begin(step)
# -> 1650     tmp_logs = self.train_function(iterator)
#    1651     if data_handler.should_sync:
#    1652         context.async_wait()
#
# File c:\Users\ssinghai6\A\lib\site-packages\keras\engine\training.py:1249, in Model.make_train_function.<locals>.train_function(iterator)
#    1247 def train_function(iterator):
#    1248     """Runs a training execution with a single step."""
# -> 1249     return step_function(self, iterator)
#
# File c:\Users\ssinghai6\A\lib\site-packages\keras\engine\training.py:1233, in Model.make_train_function.<locals>.step_function(model, iterator)
#    1229     run_step = tf.function(
#    1230         run_step, jit_compile=True, reduce_retracing=True
#    1231     )
#    1232 data = next(iterator)
# -> 1233 outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1234 outputs = reduce_per_replica(
#    1235     outputs,
#    1236     self.distribute_strategy,
#    1237     reduction=self.distribute_reduction_method,
#    1238 )
#    1239 return outputs
#
# File c:\Users\ssinghai6\A\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1316, in StrategyBase.run(***failed resolving arguments***)
#    1311 with self.scope():
#    1312   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1313   # applied when the caller is also in Eager mode.
#    1314   fn = autograph.tf_convert(
#    1315       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1316   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File c:\Users\ssinghai6\A\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2895, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    2893   kwargs = {}
#    2894 with self._container_strategy().scope():
# -> 2895   return self._call_for_each_replica(fn, args, kwargs)
#
# File c:\Users\ssinghai6\A\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3696, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    3694 def _call_for_each_replica(self, fn, args, kwargs):
#    3695   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3696     return fn(*args, **kwargs)
#
# File c:\Users\ssinghai6\A\lib\site-packages\tensorflow\python\autograph\impl\api.py:595, in call_with_unspecified_conversion_status.<locals>.wrapper(*args, **kwargs)
#     593 def wrapper(*args, **kwargs):
#     594   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 595     return func(*args, **kwargs)
#
# File c:\Users\ssinghai6\A\lib\site-packages\keras\engine\training.py:1222, in Model.make_train_function.<locals>.step_function.<locals>.run_step(data)
#    1221 def run_step(data):
# -> 1222     outputs = model.train_step(data)
#    1223     # Ensure counter is updated only if `train_step` succeeds.
#    1224     with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# File c:\Users\ssinghai6\A\lib\site-packages\keras\engine\training.py:1027, in Model.train_step(self, data)
#    1025 self._validate_target_and_loss(y, loss)
#    1026 # Run backwards pass.
# -> 1027 self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#    1028 return self.compute_metrics(x, y, y_pred, sample_weight)
#
# File c:\Users\ssinghai6\A\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py:527, in _BaseOptimizer.minimize(self, loss, var_list, tape)
#     506 """Minimize `loss` by updating `var_list`.
#     507
#     508 This method simply computes gradient using `tf.GradientTape` and calls
#    (...)
#     524   None
#     525 """
#     526 grads_and_vars = self.compute_gradients(loss, var_list, tape)
# --> 527 self.apply_gradients(grads_and_vars)
#
# File c:\Users\ssinghai6\A\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py:1140, in Optimizer.apply_gradients(self, grads_and_vars, name, skip_gradients_aggregation, **kwargs)
#    1138 if not skip_gradients_aggregation and experimental_aggregate_gradients:
#    1139     grads_and_vars = self.aggregate_gradients(grads_and_vars)
# -> 1140 return super().apply_gradients(grads_and_vars, name=name)
#
# File c:\Users\ssinghai6\A\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py:634, in _BaseOptimizer.apply_gradients(self, grads_and_vars, name)
#     632 self._apply_weight_decay(trainable_variables)
#     633 grads_and_vars = list(zip(grads, trainable_variables))
# --> 634 iteration = self._internal_apply_gradients(grads_and_vars)
#     636 # Apply variable constraints after applying gradients.
#     637 for variable in trainable_variables:
#
# File c:\Users\ssinghai6\A\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py:1166, in Optimizer._internal_apply_gradients(self, grads_and_vars)
#    1165 def _internal_apply_gradients(self, grads_and_vars):
# -> 1166     return tf.__internal__.distribute.interim.maybe_merge_call(
#    1167         self._distributed_apply_gradients_fn,
#    1168         self._distribution_strategy,
#    1169         grads_and_vars,
#    1170     )
#
# File c:\Users\ssinghai6\A\lib\site-packages\tensorflow\python\distribute\merge_call_interim.py:51, in maybe_merge_call(fn, strategy, *args, **kwargs)
#      31 """Maybe invoke `fn` via `merge_call` which may or may not be fulfilled.
#      32
#      33 The caller of this utility function requests to invoke `fn` via `merge_call`
#    (...)
#      48   The return value of the `fn` call.
#      49 """
#      50 if strategy_supports_no_merge_call():
# ---> 51   return fn(strategy, *args, **kwargs)
#      52 else:
#      53   return distribution_strategy_context.get_replica_context().merge_call(
#      54       fn, args=args, kwargs=kwargs)
#
# File c:\Users\ssinghai6\A\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py:1216, in Optimizer._distributed_apply_gradients_fn(self, distribution, grads_and_vars, **kwargs)
#    1213         return self._update_step(grad, var)
#    1215 for grad, var in grads_and_vars:
# -> 1216     distribution.extended.update(
#    1217         var, apply_grad_to_update_var, args=(grad,), group=False
#    1218     )
#    1220 if self.use_ema:
#    1221     _, var_list = zip(*grads_and_vars)
#
# File c:\Users\ssinghai6\A\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2639, in StrategyExtendedV2.update(self, var, fn, args, kwargs, group)
#    2637     return self._update(var, fn, args, kwargs, group)
#    2638 else:
# -> 2639   return self._replica_ctx_update(
#    2640       var, fn, args=args, kwargs=kwargs, group=group)
#
# File c:\Users\ssinghai6\A\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2518, in StrategyExtendedV2._replica_ctx_update(self, var, fn, args, kwargs, group)
#    2515 def merge_fn(_, *merged_args, **merged_kwargs):
#    2516   return self.update(var, fn, merged_args, merged_kwargs, group=group)
# -> 2518 return replica_context.merge_call(merge_fn, args=args, kwargs=kwargs)
#
# File c:\Users\ssinghai6\A\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3110, in ReplicaContextBase.merge_call(self, merge_fn, args, kwargs)
#    3106   kwargs = {}
#    3108 merge_fn = autograph.tf_convert(
#    3109     merge_fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 3110 return self._merge_call(merge_fn, args, kwargs)
#
# File c:\Users\ssinghai6\A\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3117, in ReplicaContextBase._merge_call(self, merge_fn, args, kwargs)
#    3114 _push_per_thread_mode(  # thread-local, so not needed with multiple threads
#    3115     distribution_strategy_context._CrossReplicaThreadMode(self._strategy))  # pylint: disable=protected-access
#    3116 try:
# -> 3117   return merge_fn(self._strategy, *args, **kwargs)
#    3118 finally:
#    3119   _pop_per_thread_mode()
#
# File c:\Users\ssinghai6\A\lib\site-packages\tensorflow\python\autograph\impl\api.py:595, in call_with_unspecified_conversion_status.<locals>.wrapper(*args, **kwargs)
#     593 def wrapper(*args, **kwargs):
#     594   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 595     return func(*args, **kwargs)
#
# File c:\Users\ssinghai6\A\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2516, in StrategyExtendedV2._replica_ctx_update.<locals>.merge_fn(_, *merged_args, **merged_kwargs)
#    2515 def merge_fn(_, *merged_args, **merged_kwargs):
# -> 2516   return self.update(var, fn, merged_args, merged_kwargs, group=group)
#
# File c:\Users\ssinghai6\A\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2637, in StrategyExtendedV2.update(self, var, fn, args, kwargs, group)
#    2634   fn = autograph.tf_convert(
#    2635       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#    2636   with self._container_strategy().scope():
# -> 2637     return self._update(var, fn, args, kwargs, group)
#    2638 else:
#    2639   return self._replica_ctx_update(
#    2640       var, fn, args=args, kwargs=kwargs, group=group)
#
# File c:\Users\ssinghai6\A\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3710, in _DefaultDistributionExtended._update(self, var, fn, args, kwargs, group)
#    3707 def _update(self, var, fn, args, kwargs, group):
#    3708   # The implementations of _update() and _update_non_slot() are identical
#    3709   # except _update() passes `var` as the first argument to `fn()`.
# -> 3710   return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#
# File c:\Users\ssinghai6\A\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3716, in _DefaultDistributionExtended._update_non_slot(self, colocate_with, fn, args, kwargs, should_group)
#    3712 def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#    3713   # TODO(josh11b): Figure out what we should be passing to UpdateContext()
#    3714   # once that value is used for something.
#    3715   with UpdateContext(colocate_with):
# -> 3716     result = fn(*args, **kwargs)
#    3717     if should_group:
#    3718       return result
#
# File c:\Users\ssinghai6\A\lib\site-packages\tensorflow\python\autograph\impl\api.py:595, in call_with_unspecified_conversion_status.<locals>.wrapper(*args, **kwargs)
#     593 def wrapper(*args, **kwargs):
#     594   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 595     return func(*args, **kwargs)
#
# File c:\Users\ssinghai6\A\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py:1213, in Optimizer._distributed_apply_gradients_fn.<locals>.apply_grad_to_update_var(var, grad)
#    1211     return self._update_step_xla(grad, var, id(self._var_key(var)))
#    1212 else:
# -> 1213     return self._update_step(grad, var)
#
# File c:\Users\ssinghai6\A\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py:224, in _BaseOptimizer._update_step(self, gradient, variable)
#     215 if self._var_key(variable) not in self._index_dict:
#     216     raise KeyError(
#     217         f"The optimizer cannot recognize variable {variable.name}. "
#     218         "This usually means you are trying to call the optimizer to "
#    (...)
#     222         "`tf.keras.optimizers.legacy.{self.__class__.__name__}."
#     223     )
# --> 224 self.update_step(gradient, variable)
#
# File c:\Users\ssinghai6\A\lib\site-packages\keras\optimizers\optimizer_experimental\adam.py:200, in Adam.update_step(self, gradient, variable)
#     198     v_hat.assign(tf.maximum(v_hat, v))
#     199     v = v_hat
# --> 200 variable.assign_sub((m * alpha) / (tf.sqrt(v) + self.epsilon))
#
# File c:\Users\ssinghai6\A\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:865, in BaseResourceVariable.assign_sub(self, delta, use_locking, name, read_value)
#     861 # TODO(apassos): this here and below is not atomic. Consider making it
#     862 # atomic if there's a way to do so without a performance cost for those who
#     863 # don't need it.
#     864 with _handle_graph(self.handle), self._assign_dependencies():
# --> 865   assign_sub_op = gen_resource_variable_ops.assign_sub_variable_op(
#     866       self.handle,
#     867       ops.convert_to_tensor(delta, dtype=self.dtype),
#     868       name=name)
#     869 if read_value:
#     870   return self._lazy_read(assign_sub_op)
#
# File c:\Users\ssinghai6\A\lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py:93, in assign_sub_variable_op(resource, value, name)
#      91 if tld.is_eager:
#      92   try:
# ---> 93     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#      94       _ctx, "AssignSubVariableOp", name, resource, value)
#      95     return _result
#      96   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# Generate predictions for the next n time steps
n = 100
last_steps = data[-time_steps:, :]
predictions = []
for i in range(n):
    next_step = model.predict(last_steps.reshape(1, time_steps, num_inputs))
    predictions.append(next_step)
    last_steps = np.concatenate((last_steps[1:], next_step), axis=0)

# Reshape predictions to be 2-dimensional in the form (time steps, features)
predictions = np.array(predictions).reshape(n, num_inputs)

# Inverse transform the predictions back to the original scale
predictions = scaler.inverse_transform(predictions)

# Print the predictions
print(predictions)
# Out:
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s
#  [1.8495055e-09 4.6885918e+01 2.5636953e-01 3.0120518e+01 2.8796223e+01
#   4.7016073e-02]
#  [1.8568644e-09 4.6876415e+01 2.5397870e-01 3.0163784e+01 2.8887291e+01
#   4.6732143e-02]
#  [1.8649380e-09 4.6954788e+01 2.5142518e-01 3.0127623e+01 2.9032583e+01
#   4.6599586e-02]
#  [1.8688440e-09 4.7079121e+01 2.5001144e-01 3.0013357e+01 2.9141905e+01
#   4.6657119e-02]
#  [1.8661293e-09 4.7196957e+01 2.5065082e-01 2.9891300e+01 2.9133604e+01
#   4.6892922e-02]
#  [1.8598884e-09 4.7186607e+01 2.5266752e-01 2.9890505e+01 2.9029676e+01
#   4.7184806e-02]
#  [1.8529337e-09 4.7108738e+01 2.5493941e-01 2.9960663e+01 2.8894554e+01
#   4.7324479e-02]
#  [1.8497206e-09 4.6986103e+01 2.5610700e-01 3.0051506e+01 2.8818951e+01
#   4.7202516e-02]
#  [1.8519719e-09 4.6911144e+01 2.5552315e-01 3.0109238e+01 2.8833704e+01
#   4.6956539e-02]
#  [1.8585664e-09 4.6924782e+01 2.5333750e-01 3.0132622e+01 2.8922579e+01
#   4.6743058e-02]
#  [1.8645314e-09 4.7004478e+01 2.5145829e-01 3.0086262e+01 2.9038290e+01
#   4.6672802e-02]
#  [1.8664765e-09 4.7110920e+01 2.5061908e-01 2.9985092e+01 2.9107630e+01
#   4.6753265e-02]
#  [1.8633206e-09 4.7180412e+01 2.5155056e-01 2.9906084e+01 2.9080097e+01
#   4.6972044e-02]
#  [1.8579680e-09 4.7161083e+01 2.5329909e-01 2.9926348e+01 2.8982122e+01
#   4.7189608e-02]
#  [1.8528541e-09 4.7072639e+01 2.5500903e-01 2.9990700e+01 2.8881199e+01
#   4.7243983e-02]
#  [1.8513382e-09 4.6978321e+01 2.5559470e-01 3.0059210e+01 2.8841383e+01
#   4.7109507e-02]
#  [1.8543245e-09 4.6935959e+01 2.5471234e-01 3.0100073e+01 2.8870716e+01
#   4.6913825e-02]
#  [1.8597861e-09 4.6970894e+01 2.5286624e-01 3.0100468e+01 2.8952158e+01
#   4.6766952e-02]
#  [1.8638224e-09 4.7048889e+01 2.5158209e-01 3.0049900e+01 2.9037518e+01
#   4.6740651e-02]
#  [1.8641977e-09 4.7129147e+01 2.5127146e-01 2.9967024e+01 2.9074043e+01
#   4.6837386e-02]
#  [1.8610956e-09 4.7157314e+01 2.5228673e-01 2.9927523e+01 2.9033039e+01
#   4.7030106e-02]
#  [1.8566492e-09 4.7129051e+01 2.5372016e-01 2.9954475e+01 2.8949448e+01
#   4.7179330e-02]]

# %%
new_db =[]
new_elas = []
new_density = []
new_v = []
new_phi = []
new_psi =[]
new_c = []
for i in range(n):
    # new_db.append(predictions[i][0])
    new_density.append(predictions[i][0])
    new_elas.append(predictions[i][1])
    new_v.append(predictions[i][2])
    new_phi.append(predictions[i][3])
    new_psi.append(predictions[i][4])
    new_c.append(predictions[i][5])

# %%
db =[]
elas= []
v = []
phi = []
psi = []
c = []
density = []
for i in range(100):
    db.append(para[i][0])
    density.append(para[i][1])
    elas.append(para[i][2])
    v.append(para[i][3])
    phi.append(para[i][4])
    psi.append(para[i][5])
    c.append(para[i][6])

# %%
len(elas+new_elas)
# Out:
# 200

# %%
import matplotlib.pyplot as plt

# Create the data set
time = list(range(2*no))
value = elas+new_elas
label = ['known']*no + ['predicted']*no

# Plot the data
plt.plot(time[:no], value[:no], label='known')
plt.plot(time[no:], value[no:], label='predicted', linestyle='--')
plt.legend()
plt.xlabel('Time')
plt.ylabel('Elastic Modulus')
plt.show()

# %%
import matplotlib.pyplot as plt

# Create the data set
time = list(range(2*no))
value = density+new_density
label = ['known']*no + ['predicted']*no

# Plot the data
plt.plot(time[:no], value[:no], label='known')
plt.plot(time[no:], value[no:], label='predicted', linestyle='--')
plt.legend()
plt.xlabel('Time Step')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt

# Create the data set
time = list(range(2*no))
value = v+new_v
label = ['known']*no + ['predicted']*no

# Plot the data
plt.plot(time[:no], value[:no], label='known')
plt.plot(time[no:], value[no:], label='predicted', linestyle='--')
plt.legend()
plt.xlabel('Time Step')
plt.ylabel('v')
plt.show()

# %%
import matplotlib.pyplot as plt

# Create the data set
time = list(range(2*no))
value = phi+new_phi
label = ['known']*no+ ['predicted']*no

# Plot the data
plt.plot(time[:no], value[:no], label='known')
plt.plot(time[no:], value[no:], label='predicted', linestyle='--')
plt.legend()
plt.xlabel('Time Step')
plt.ylabel('phi')
plt.show()

# %%
import matplotlib.pyplot as plt

# Create the data set
time = list(range(2*no))
value = psi+new_psi
label = ['known']*40 + ['predicted']*40

# Plot the data
plt.plot(time[:no], value[:no], label='known')
plt.plot(time[no:], value[no:], label='predicted', linestyle='--')
plt.legend()
plt.xlabel('Time Step')
plt.ylabel('psi')
plt.show()

# %%
import matplotlib.pyplot as plt

# Create the data set
time = list(range(2*no))
value = c+new_c
label = ['known']*no + ['predicted']*no

# Plot the data
plt.plot(time[:no], value[:no], label='known')
plt.plot(time[no:], value[no:], label='predicted', linestyle='--')
plt.legend()
plt.xlabel('Time Step')
plt.ylabel('c')
plt.show()

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2, 3, figsize=(15, 10))

time = list(range(2*no))

# Plot Elastic Modulus
axs[0, 0].plot(time[:no], elas, label='known')
axs[0, 0].plot(time[no:], new_elas, label='predicted', linestyle='--')
axs[0, 0].set_xlabel('Time')
axs[0, 0].set_ylabel('Elastic Modulus')
axs[0, 0].legend()

# Plot Density
axs[0, 1].plot(time[:no], density, label='known')
axs[0, 1].plot(time[no:], new_density, label='predicted', linestyle='--')
axs[0, 1].set_xlabel('Time Step')
axs[0, 1].set_ylabel('Density')
axs[0, 1].legend()

# Plot v
axs[0, 2].plot(time[:no], v, label='known')
axs[0, 2].plot(time[no:], new_v, label='predicted', linestyle='--')
axs[0, 2].set_xlabel('Time Step')
axs[0, 2].set_ylabel('v')
axs[0, 2].legend()

# Plot phi
axs[1, 0].plot(time[:no], phi, label='known')
axs[1, 0].plot(time[no:], new_phi, label='predicted', linestyle='--')
axs[1, 0].set_xlabel('Time Step')
axs[1, 0].set_ylabel('phi')
axs[1, 0].legend()

# Plot psi
axs[1, 1].plot(time[:no], psi, label='known')
axs[1, 1].plot(time[no:], new_psi, label='predicted', linestyle='--')
axs[1, 1].set_xlabel('Time Step')
axs[1, 1].set_ylabel('psi')
axs[1, 1].legend()

# Plot c
axs[1, 2].plot(time[:no], c, label='known')
axs[1, 2].plot(time[no:], new_c, label='predicted', linestyle='--')
axs[1, 2].set_xlabel('Time Step')
# 38  3.0        37.712280  2.263413e-09  0.309306  39.005894  35.825291
# 39  3.0        28.972906  2.217973e-09  0.263613  41.455227  34.515171
#
#            c
# 0   0.015993
# 1   0.024908
# 2   0.017166
# 3   0.026586
# 4   0.027253
# 5   0.026391
# 6   0.025388
# 7   0.026715
# 8   0.027507
# 9   0.028091
# 10  0.028667
# 11  0.028146
# 12  0.028197
# 13  0.027787
# 14  0.027714
# 15  0.027836
# 16  0.029161
# 17  0.031505
# 18  0.035766
# 19  0.040185
# 20  0.044728
# 21  0.047396
# 22  0.048055
# 23  0.044437
# 24  0.036520
# 25  0.027512
# 26  0.025519
# 27  0.024552
# 28  0.024886
# 29  0.030388
# 30  0.038925
# 31  0.046704
# 32  0.053910
# 33  0.055585
# 34  0.048021
# 35  0.033815
# 36  0.032851
# 37  0.035676
# 38  0.030051
# 39  0.025626

# %%
df_new[(df_new['d/b']>3) & (df_new['d/b']<10)].mean()
# Out:
# d/b                9.491686e+00
# Elastic Modulus    3.030176e+01
# Density            2.069822e-09
# v                  2.833264e-01
# phi                3.012941e+01
# psi                3.021655e+01
# c                  5.002952e-02
# dtype: float32

# %%
df_new['d_b']>3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ssinghai6\A\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\ssinghai6\A\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\ssinghai6\A\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'd_b'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# d:\Sanshrit\VIP\Archive\RNN_parametrized_Pdistri_Reverse.ipynb Cell 22 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Sanshrit/VIP/Archive/RNN_parametrized_Pdistri_Reverse.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> df_new['d_b']>3
#
# File c:\Users\ssinghai6\A\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Users\ssinghai6\A\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'd_b'

# %%
from flask import Flask, request, render_template
from keras.models import load_model
import tensorflow_addons as tfa
import numpy as np
import sklearn as sk
import pandas as pd
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
# Out:
# c:\Users\ssinghai6\A\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.8.0 and strictly below 2.11.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.11.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
def ANN1_Predict(model1,scaler,d_b,density,E,v,phi,psi,c):
    a1 = model1.predict(scaler.transform([[d_b,density,E,v,phi,psi,c]]))
    a1 = np.reshape(a1,-1)
    return a1

# %%
def data_ses (step_length):
    from flask import Flask, request, render_template
    from keras.models import load_model
    import tensorflow_addons as tfa
    import numpy as np
    import sklearn as sk
    import pandas as pd
    from scipy.interpolate import griddata
    import matplotlib.pyplot as plt
    half = step_length
    import numpy as np
    depth = []
    depth[0:half] = np.linspace(3,10,half)
    depth[half:2*half] = np.linspace(10,3,half)
    no = len(depth)
    list_Elas = []
    list_density = []
    list_v =[]
    list_phi = []
    list_psi =[]
    list_c =[]

    elas_mus = [50, 20, 55, 50, 40, 30, 60]
    elas_sigmas = [8, 6, 5, 3.5, 3, 2, 1]

    density_mus = [2.0e-09,1.80e-09,2.2e-09, 1.90e-09,1.75e-09,2.1e-09,1.6e-09]
    density_sigmas = [0.3e-09, 0.25e-09, 0.2e-09, 0.17e-09, 0.15e-09, 0.11e-09, 0.1e-09]

    v_mus = [0.24,0.28,0.35,0.3,0.23,0.36,0.25]
    v_sigmas = [0.07,0.05,0.04,0.03,0.025,0.022,0.02]

    phi_mus = [40,20,27,32,35,28,33]
    phi_sigmas = [4,3.5,3,2.5,2,1.5,1]

    psi_mus = [20,10,13.5,16,17.5,14,11]
    psi_sigmas = [6,4,3,2.5,2,1.5,1]

    c_mus = [0.015,0.08,0.018,0.055,0.085,0.05,0.019]
    c_sigmas = [0.006,0.004,0.003,0.0025,0.002,0.0015,0.001]


    for d_b in depth:
        if d_b >=3 and d_b<4:
            k = 0 
            mu_density,mu_elas,mu_v,mu_phi,mu_psi,mu_c = density_mus[k],elas_mus[k],v_mus[k],phi_mus[k],psi_mus[k],c_mus[k]
            sigma_density, sigma_elas, sigma_v, sigma_phi, sigma_psi, sigma_c = density_sigmas[k],elas_sigmas[k],v_sigmas[k],phi_sigmas[k],psi_sigmas[k],c_sigmas[k]
            
        if d_b >=4 and d_b<5:
            k = 1
            mu_density,mu_elas,mu_v,mu_phi,mu_psi,mu_c = density_mus[k],elas_mus[k],v_mus[k],phi_mus[k],psi_mus[k],c_mus[k]
            sigma_density, sigma_elas, sigma_v, sigma_phi, sigma_psi, sigma_c = density_sigmas[k],elas_sigmas[k],v_sigmas[k],phi_sigmas[k],psi_sigmas[k],c_sigmas[k]
        if d_b >=5 and d_b<6:
            k = 2 
            mu_density,mu_elas,mu_v,mu_phi,mu_psi,mu_c = density_mus[k],elas_mus[k],v_mus[k],phi_mus[k],psi_mus[k],c_mus[k]
            sigma_density, sigma_elas, sigma_v, sigma_phi, sigma_psi, sigma_c = density_sigmas[k],elas_sigmas[k],v_sigmas[k],phi_sigmas[k],psi_sigmas[k],c_sigmas[k]
        if d_b >=6 and d_b<7:
            k = 3 
            mu_density,mu_elas,mu_v,mu_phi,mu_psi,mu_c = density_mus[k],elas_mus[k],v_mus[k],phi_mus[k],psi_mus[k],c_mus[k]
            sigma_density, sigma_elas, sigma_v, sigma_phi, sigma_psi, sigma_c = density_sigmas[k],elas_sigmas[k],v_sigmas[k],phi_sigmas[k],psi_sigmas[k],c_sigmas[k]
            
        if d_b >=7 and d_b<8:
            k = 4 
            mu_density,mu_elas,mu_v,mu_phi,mu_psi,mu_c = density_mus[k],elas_mus[k],v_mus[k],phi_mus[k],psi_mus[k],c_mus[k]
            sigma_density, sigma_elas, sigma_v, sigma_phi, sigma_psi, sigma_c = density_sigmas[k],elas_sigmas[k],v_sigmas[k],phi_sigmas[k],psi_sigmas[k],c_sigmas[k]
            
        if d_b >=8 and d_b<9:
            k = 5
            mu_density,mu_elas,mu_v,mu_phi,mu_psi,mu_c = density_mus[k],elas_mus[k],v_mus[k],phi_mus[k],psi_mus[k],c_mus[k]
            sigma_density, sigma_elas, sigma_v, sigma_phi, sigma_psi, sigma_c = density_sigmas[k],elas_sigmas[k],v_sigmas[k],phi_sigmas[k],psi_sigmas[k],c_sigmas[k]
            
        if d_b >=9 and d_b<10:
            k = 6 
            mu_density,mu_elas,mu_v,mu_phi,mu_psi,mu_c = density_mus[k],elas_mus[k],v_mus[k],phi_mus[k],psi_mus[k],c_mus[k]
            sigma_density, sigma_elas, sigma_v, sigma_phi, sigma_psi, sigma_c = density_sigmas[k],elas_sigmas[k],v_sigmas[k],phi_sigmas[k],psi_sigmas[k],c_sigmas[k]
                
        list_Elas.append(np.random.normal(mu_elas, sigma_elas))
        list_density.append(np.random.normal(mu_density, sigma_density))
        list_v.append(np.random.normal(mu_v, sigma_v))
        list_phi.append(np.random.normal(mu_phi, sigma_phi))
        list_psi.append(np.random.normal(mu_psi, sigma_psi))
        list_c.append(np.random.normal(mu_c, sigma_c))
    return depth,list_Elas,list_density,list_v,list_phi, list_psi, list_c

# %%
step_length = 30
depth,list_Elas,list_density,list_v,list_phi, list_psi, list_c  = data_ses(step_length)

# %%
interval = 6
from flask import Flask, request, render_template
from keras.models import load_model
import tensorflow_addons as tfa
import numpy as np
import sklearn as sk
import pandas as pd
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
import numpy as np
#d_b_list = arr[:,0]
#E_list = arr[:,1]
d_b_list = depth
E_list = list_Elas
density_list = list_density
v_list = list_v
phi_list = list_phi
psi_list = list_psi
c_list = list_c
no = len(depth)
ANN1 = 'Final_ANN1.h5'
model1 = load_model(ANN1,custom_objects={'RSquare' : tfa.metrics.RSquare})
scaler = pd.read_pickle('scale_ann1.pkl')
batch = 32
    
result = []
para = []
paras = []
for i in range(no):
    #d_b,density,E,v,phi,psi,c = d_b_list[i],np.random.choice(density_list),E_list[i],np.random.choice(v_list),np.random.choice(phi_list),np.random.choice(psi_list),np.random.choice(c_list)
    d_b,density,E,v,phi,psi,c = depth[i],density_list[i],E_list[i],v_list[i],phi_list[i],psi_list[i],c_list[i]
    temp1 = [density,E,v,phi,psi,c]
    temp = [d_b,density,E,v,phi,psi,c]
    paras.append(temp1)
    para.append(temp)
    res_temp = ANN1_Predict(model1,scaler,d_b,density,E,v,phi,psi,c)
    result.append(res_temp)
import numpy as np
import matplotlib.pyplot as plt


# Create x-axis values
x = np.arange(no)
para1 = np.reshape(para,(no,7))
# Generate some random y values
para_d_b = para1[:,0]
para_density = para1[:,1]
para_elastic = para1[:,2]
para_v = para1[:,3]
para_phi = para1[:,4]
para_psi = para1[:,5]
para_c = para1[:,6]

# Create a figure with three subplots
fig, axs = plt.subplots(nrows=7, ncols=1, figsize=(8, 8))

# Plot each line in a separate subplot
axs[0].plot(x,para_d_b )
axs[0].set_title('d_b')
axs[1].plot(x, para_density)
axs[1].set_title('Density')
axs[2].plot(x, para_elastic)
axs[2].set_title('Elastic Modulus')
axs[3].plot(x, para_v)
axs[3].set_title('v')
axs[4].plot(x, para_phi)
axs[4].set_title('phi')
axs[5].plot(x, para_psi)
axs[5].set_title('psi')
axs[6].plot(x, para_c)
axs[6].set_title('c')

# Add x and y axis labels
for ax in axs:
    ax.set_xlabel('Time Step')
    ax.set_ylabel('Properties')

# Add some space between the subplots
fig.tight_layout()

# Display the plot
plt.show()

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, LSTM, GRU
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import tensorflow_addons as tfa

# Define the number of input parameters and time steps
num_inputs = 6
time_steps = interval
# Generate some random data for demonstration purposes
data = paras

# Normalize the data
scaler = MinMaxScaler()
data = scaler.fit_transform(data)

# Create the training data using a sliding window approach
X_train = []
y_train = []
for i in range(time_steps, len(data)):
    X_train.append(data[i-time_steps:i, :])
    y_train.append(data[i, :])

X_train = np.array(X_train)
y_train = np.array(y_train)

# Reshape the input data to be 3-dimensional in the form (samples, time steps, features)
X_train = np.reshape(X_train, (X_train.shape[0], time_steps, num_inputs))

# Define the LSTM model
model = Sequential()
model.add(LSTM(300, input_shape=(time_steps, num_inputs), return_sequences=True))
model.add(LSTM(200, activation="relu", return_sequences=True))
model.add(LSTM(100, activation="relu"))
model.add(Dense(num_inputs))
metric = tfa.metrics.r_square.RSquare()
model.compile(optimizer='adam', loss='mse', metrics=[metric], run_eagerly=True)

# Train the model
model.fit(X_train, y_train, epochs=200, batch_size= batch)

# Generate predictions for the next n time steps
n = no
last_steps = data[-time_steps:, :]
predictions = []
for i in range(n):
    next_step = model.predict(last_steps.reshape(1, time_steps, num_inputs))
    predictions.append(next_step)
    last_steps = np.concatenate((last_steps[1:], next_step), axis=0)

# Reshape predictions to be 2-dimensional in the form (time steps, features)
predictions = np.array(predictions).reshape(n, num_inputs)

# Inverse transform the predictions back to the original scale
predictions = scaler.inverse_transform(predictions)

# Print the predictions
print(predictions)

new_db =[]
new_elas = []
new_density = []
new_v = []
new_phi = []
new_psi =[]
new_c = []
for i in range(n):
    # new_db.append(predictions[i][0])
    new_density.append(predictions[i][0])
    new_elas.append(predictions[i][1])
    new_v.append(predictions[i][2])
    new_phi.append(predictions[i][3])
    new_psi.append(predictions[i][4])
    new_c.append(predictions[i][5])
    
db =[]
elas= []
v = []
phi = []
psi = []
c = []
density = []
for i in range(no):
    db.append(para[i][0])
    density.append(para[i][1])
    elas.append(para[i][2])
    v.append(para[i][3])
    phi.append(para[i][4])
    psi.append(para[i][5])
    c.append(para[i][6])
    
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2, 3, figsize=(15, 10))

time = list(range(2*no))

# Plot Elastic Modulus
axs[0, 0].plot(time[:no], elas, label='known')
axs[0, 0].plot(time[no:], new_elas, label='predicted', linestyle='--')
axs[0, 0].set_xlabel('Time')
axs[0, 0].set_ylabel('Elastic Modulus')
axs[0, 0].legend()

# Plot Density
axs[0, 1].plot(time[:no], density, label='known')
axs[0, 1].plot(time[no:], new_density, label='predicted', linestyle='--')
axs[0, 1].set_xlabel('Time Step')
axs[0, 1].set_ylabel('Density')
axs[0, 1].legend()

# Plot v
axs[0, 2].plot(time[:no], v, label='known')
axs[0, 2].plot(time[no:], new_v, label='predicted', linestyle='--')
axs[0, 2].set_xlabel('Time Step')
axs[0, 2].set_ylabel('v')
axs[0, 2].legend()

# Plot phi
axs[1, 0].plot(time[:no], phi, label='known')
axs[1, 0].plot(time[no:], new_phi, label='predicted', linestyle='--')
axs[1, 0].set_xlabel('Time Step')
axs[1, 0].set_ylabel('phi')
axs[1, 0].legend()

# Plot psi
axs[1, 1].plot(time[:no], psi, label='known')
axs[1, 1].plot(time[no:], new_psi, label='predicted', linestyle='--')
axs[1, 1].set_xlabel('Time Step')
axs[1, 1].set_ylabel('psi')
axs[1, 1].legend()

# Plot c
axs[1, 2].plot(time[:no], c, label='known')
axs[1, 2].plot(time[no:], new_c, label='predicted', linestyle='--')
axs[1, 2].set_xlabel('Time Step')
axs[1, 2].set_ylabel('c')
axs[1, 2].legend()
# Out:
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# Epoch 1/200
# 2/2 [==============================] - 0s 174ms/step - loss: 0.3147 - r_square: -5.3974
# Epoch 2/200
# 2/2 [==============================] - 0s 179ms/step - loss: 0.2734 - r_square: -4.4769
# Epoch 3/200
# 2/2 [==============================] - 0s 172ms/step - loss: 0.2130 - r_square: -3.1102
# Epoch 4/200
# 2/2 [==============================] - 0s 190ms/step - loss: 0.1189 - r_square: -1.0860
# Epoch 5/200
# 2/2 [==============================] - 0s 178ms/step - loss: 0.1163 - r_square: -1.7494
# Epoch 6/200
# 2/2 [==============================] - 0s 194ms/step - loss: 0.0736 - r_square: -0.4494
# Epoch 7/200
# 2/2 [==============================] - 0s 182ms/step - loss: 0.0694 - r_square: -0.2325
# Epoch 8/200
# 2/2 [==============================] - 0s 188ms/step - loss: 0.0722 - r_square: -0.3046
# Epoch 9/200
# 2/2 [==============================] - 0s 179ms/step - loss: 0.0680 - r_square: -0.2566
# Epoch 10/200
# 2/2 [==============================] - 0s 190ms/step - loss: 0.0684 - r_square: -0.2511
# Epoch 11/200
# 2/2 [==============================] - 0s 197ms/step - loss: 0.0684 - r_square: -0.2319
# Epoch 12/200
# 2/2 [==============================] - 0s 193ms/step - loss: 0.0631 - r_square: -0.1528
# Epoch 13/200
# 2/2 [==============================] - 0s 182ms/step - loss: 0.0618 - r_square: -0.1465
# Epoch 14/200
# 2/2 [==============================] - 0s 196ms/step - loss: 0.0611 - r_square: -0.1176
# Epoch 15/200
# 2/2 [==============================] - 0s 181ms/step - loss: 0.0597 - r_square: -0.0612
# Epoch 16/200
# 2/2 [==============================] - 0s 172ms/step - loss: 0.0596 - r_square: -0.0508
# Epoch 17/200
# 2/2 [==============================] - 0s 193ms/step - loss: 0.0601 - r_square: -0.0717
# Epoch 18/200
# 2/2 [==============================] - 0s 190ms/step - loss: 0.0588 - r_square: -0.0461
# Epoch 19/200
# 2/2 [==============================] - 0s 198ms/step - loss: 0.0588 - r_square: -0.0318
# Epoch 20/200
# 2/2 [==============================] - 0s 180ms/step - loss: 0.0591 - r_square: -0.0299
# Epoch 21/200
# 2/2 [==============================] - 0s 198ms/step - loss: 0.0584 - r_square: -0.0182
# Epoch 22/200
# 2/2 [==============================] - 0s 182ms/step - loss: 0.0572 - r_square: 1.2219e-05
# Epoch 23/200
# 2/2 [==============================] - 0s 183ms/step - loss: 0.0573 - r_square: -0.0021
# Epoch 24/200
# 2/2 [==============================] - 0s 184ms/step - loss: 0.0571 - r_square: 0.0067
# Epoch 25/200
# 2/2 [==============================] - 0s 189ms/step - loss: 0.0565 - r_square: 0.0201
# Epoch 26/200
# 2/2 [==============================] - 0s 174ms/step - loss: 0.0564 - r_square: 0.0146
# Epoch 27/200
# 2/2 [==============================] - 0s 193ms/step - loss: 0.0560 - r_square: 0.0186
# Epoch 28/200
# 2/2 [==============================] - 0s 185ms/step - loss: 0.0555 - r_square: 0.0322
# Epoch 29/200
# 2/2 [==============================] - 0s 198ms/step - loss: 0.0548 - r_square: 0.0463
# Epoch 30/200
# 2/2 [==============================] - 0s 199ms/step - loss: 0.0542 - r_square: 0.0555
# Epoch 31/200
# 2/2 [==============================] - 0s 178ms/step - loss: 0.0538 - r_square: 0.0614
# Epoch 32/200
# 2/2 [==============================] - 0s 187ms/step - loss: 0.0530 - r_square: 0.0712
# Epoch 33/200
# 2/2 [==============================] - 0s 177ms/step - loss: 0.0524 - r_square: 0.0788
# Epoch 34/200
# 2/2 [==============================] - 0s 196ms/step - loss: 0.0523 - r_square: 0.0835
# Epoch 35/200
# 2/2 [==============================] - 0s 180ms/step - loss: 0.0506 - r_square: 0.1012
# Epoch 36/200
# 2/2 [==============================] - 0s 186ms/step - loss: 0.0499 - r_square: 0.1101
# Epoch 37/200
# 2/2 [==============================] - 0s 188ms/step - loss: 0.0497 - r_square: 0.1150
# Epoch 38/200
# 2/2 [==============================] - 0s 183ms/step - loss: 0.0481 - r_square: 0.1336
# Epoch 39/200
# 2/2 [==============================] - 0s 189ms/step - loss: 0.0477 - r_square: 0.1395
# Epoch 40/200
# 2/2 [==============================] - 0s 170ms/step - loss: 0.0475 - r_square: 0.1409
# Epoch 41/200
# 2/2 [==============================] - 0s 195ms/step - loss: 0.0460 - r_square: 0.1590
# Epoch 42/200
# 2/2 [==============================] - 0s 181ms/step - loss: 0.0460 - r_square: 0.1618
# Epoch 43/200
# 2/2 [==============================] - 0s 184ms/step - loss: 0.0455 - r_square: 0.1670
# Epoch 44/200
# 2/2 [==============================] - 0s 184ms/step - loss: 0.0443 - r_square: 0.1903
# Epoch 45/200
# 2/2 [==============================] - 0s 201ms/step - loss: 0.0446 - r_square: 0.1860
# Epoch 46/200
# 2/2 [==============================] - 0s 180ms/step - loss: 0.0452 - r_square: 0.1842
# Epoch 47/200
# 2/2 [==============================] - 0s 177ms/step - loss: 0.0453 - r_square: 0.1850
# Epoch 48/200
# 2/2 [==============================] - 0s 190ms/step - loss: 0.0437 - r_square: 0.1931
# Epoch 49/200
# 2/2 [==============================] - 0s 188ms/step - loss: 0.0443 - r_square: 0.1916
# Epoch 50/200
# 2/2 [==============================] - 0s 191ms/step - loss: 0.0438 - r_square: 0.1972
# Epoch 51/200
# 2/2 [==============================] - 0s 181ms/step - loss: 0.0431 - r_square: 0.2086
# Epoch 52/200
# 2/2 [==============================] - 0s 198ms/step - loss: 0.0424 - r_square: 0.2241
# Epoch 53/200
# 2/2 [==============================] - 0s 182ms/step - loss: 0.0434 - r_square: 0.2105
# Epoch 54/200
# 2/2 [==============================] - 0s 187ms/step - loss: 0.0443 - r_square: 0.1956
# Epoch 55/200
# 2/2 [==============================] - 0s 173ms/step - loss: 0.0419 - r_square: 0.2375
# Epoch 56/200
# 2/2 [==============================] - 0s 180ms/step - loss: 0.0445 - r_square: 0.1930
# Epoch 57/200
# 2/2 [==============================] - 0s 194ms/step - loss: 0.0410 - r_square: 0.2392
# Epoch 58/200
# 2/2 [==============================] - 0s 170ms/step - loss: 0.0421 - r_square: 0.2264
# Epoch 59/200
# 2/2 [==============================] - 0s 190ms/step - loss: 0.0406 - r_square: 0.2474
# Epoch 60/200
# 2/2 [==============================] - 0s 194ms/step - loss: 0.0404 - r_square: 0.2504
# Epoch 61/200
# 2/2 [==============================] - 0s 165ms/step - loss: 0.0404 - r_square: 0.2495
# Epoch 62/200
# 2/2 [==============================] - 0s 185ms/step - loss: 0.0399 - r_square: 0.2574
# Epoch 63/200
# 2/2 [==============================] - 0s 197ms/step - loss: 0.0397 - r_square: 0.2594
# Epoch 64/200
# 2/2 [==============================] - 0s 171ms/step - loss: 0.0400 - r_square: 0.2590
# Epoch 65/200
# 2/2 [==============================] - 0s 179ms/step - loss: 0.0390 - r_square: 0.2710
# Epoch 66/200
# 2/2 [==============================] - 0s 186ms/step - loss: 0.0411 - r_square: 0.2403
# Epoch 67/200
# 2/2 [==============================] - 0s 187ms/step - loss: 0.0385 - r_square: 0.2809
# Epoch 68/200
# 2/2 [==============================] - 0s 195ms/step - loss: 0.0387 - r_square: 0.2811
# Epoch 69/200
# 2/2 [==============================] - 0s 192ms/step - loss: 0.0395 - r_square: 0.2699
# Epoch 70/200
# 2/2 [==============================] - 0s 185ms/step - loss: 0.0384 - r_square: 0.2849
# Epoch 71/200
# 2/2 [==============================] - 0s 171ms/step - loss: 0.0381 - r_square: 0.2888
# Epoch 72/200
# 2/2 [==============================] - 0s 184ms/step - loss: 0.0387 - r_square: 0.2822
# Epoch 73/200
# 2/2 [==============================] - 0s 187ms/step - loss: 0.0390 - r_square: 0.2824
# Epoch 74/200
# 2/2 [==============================] - 0s 172ms/step - loss: 0.0363 - r_square: 0.3173
# Epoch 75/200
# 2/2 [==============================] - 0s 184ms/step - loss: 0.0392 - r_square: 0.2802
# Epoch 76/200
# 2/2 [==============================] - 0s 182ms/step - loss: 0.0362 - r_square: 0.3194
# Epoch 77/200
# 2/2 [==============================] - 0s 190ms/step - loss: 0.0364 - r_square: 0.3193
# Epoch 78/200
# 2/2 [==============================] - 0s 191ms/step - loss: 0.0375 - r_square: 0.3098
# Epoch 79/200
# 2/2 [==============================] - 0s 190ms/step - loss: 0.0356 - r_square: 0.3295
# Epoch 80/200
# 2/2 [==============================] - 0s 185ms/step - loss: 0.
200
# 2/2 [==============================] - 0s 186ms/step - loss: 0.0256 - r_square: 0.4985
# Epoch 125/200
# 2/2 [==============================] - 0s 196ms/step - loss: 0.0251 - r_square: 0.4964
# Epoch 126/200
# 2/2 [==============================] - 0s 182ms/step - loss: 0.0249 - r_square: 0.5025
# Epoch 127/200
# 2/2 [==============================] - 0s 192ms/step - loss: 0.0247 - r_square: 0.5112
# Epoch 128/200
# 2/2 [==============================] - 0s 191ms/step - loss: 0.0235 - r_square: 0.5314
# Epoch 129/200
# 2/2 [==============================] - 0s 185ms/step - loss: 0.0234 - r_square: 0.5333
# Epoch 130/200
# 2/2 [==============================] - 0s 188ms/step - loss: 0.0229 - r_square: 0.5433
# Epoch 131/200
# 2/2 [==============================] - 0s 189ms/step - loss: 0.0221 - r_square: 0.5515
# Epoch 132/200
# 2/2 [==============================] - 0s 193ms/step - loss: 0.0237 - r_square: 0.5483
# Epoch 133/200
# 2/2 [==============================] - 0s 186ms/step - loss: 0.0237 - r_square: 0.5262
# Epoch 134/200
# 2/2 [==============================] - 0s 187ms/step - loss: 0.0218 - r_square: 0.5659
# Epoch 135/200
# 2/2 [==============================] - 0s 190ms/step - loss: 0.0207 - r_square: 0.5864
# Epoch 136/200
# 2/2 [==============================] - 0s 188ms/step - loss: 0.0221 - r_square: 0.5630
# Epoch 137/200
# 2/2 [==============================] - 0s 204ms/step - loss: 0.0215 - r_square: 0.5729
# Epoch 138/200
# 2/2 [==============================] - 0s 183ms/step - loss: 0.0218 - r_square: 0.5697
# Epoch 139/200
# 2/2 [==============================] - 0s 186ms/step - loss: 0.0196 - r_square: 0.6070
# Epoch 140/200
# 2/2 [==============================] - 0s 184ms/step - loss: 0.0204 - r_square: 0.6023
# Epoch 141/200
# 2/2 [==============================] - 0s 174ms/step - loss: 0.0196 - r_square: 0.6149
# Epoch 142/200
# 2/2 [==============================] - 0s 190ms/step - loss: 0.0185 - r_square: 0.6274
# Epoch 143/200
# 2/2 [==============================] - 0s 175ms/step - loss: 0.0187 - r_square: 0.6169
# Epoch 144/200
# 2/2 [==============================] - 0s 180ms/step - loss: 0.0176 - r_square: 0.6442
# Epoch 145/200
# 2/2 [==============================] - 0s 186ms/step - loss: 0.0192 - r_square: 0.6090
# Epoch 146/200
# 2/2 [==============================] - 0s 187ms/step - loss: 0.0176 - r_square: 0.6519
# Epoch 147/200
# 2/2 [==============================] - 0s 189ms/step - loss: 0.0204 - r_square: 0.6011
# Epoch 148/200
# 2/2 [==============================] - 0s 189ms/step - loss: 0.0188 - r_square: 0.6327
# Epoch 149/200
# 2/2 [==============================] - 0s 182ms/step - loss: 0.0208 - r_square: 0.5941
# Epoch 150/200
# 2/2 [==============================] - 0s 190ms/step - loss: 0.0169 - r_square: 0.6609
# Epoch 151/200
# 2/2 [==============================] - 0s 194ms/step - loss: 0.0181 - r_square: 0.6361
# Epoch 152/200
# 2/2 [==============================] - 0s 176ms/step - loss: 0.0172 - r_square: 0.6540
# Epoch 153/200
# 2/2 [==============================] - 0s 180ms/step - loss: 0.0180 - r_square: 0.6483
# Epoch 154/200
# 2/2 [==============================] - 0s 201ms/step - loss: 0.0156 - r_square: 0.6849
# Epoch 155/200
# 2/2 [==============================] - 0s 195ms/step - loss: 0.0160 - r_square: 0.6751
# Epoch 156/200
# 2/2 [==============================] - 0s 197ms/step - loss: 0.0151 - r_square: 0.6934
# Epoch 157/200
# 2/2 [==============================] - 0s 189ms/step - loss: 0.0155 - r_square: 0.6911
# Epoch 158/200
# 2/2 [==============================] - 0s 184ms/step - loss: 0.0147 - r_square: 0.7049
# Epoch 159/200
# 2/2 [==============================] - 0s 190ms/step - loss: 0.0147 - r_square: 0.7015
# Epoch 160/200
# 2/2 [==============================] - 0s 179ms/step - loss: 0.0139 - r_square: 0.7147
# Epoch 161/200
# 2/2 [==============================] - 0s 179ms/step - loss: 0.0136 - r_square: 0.7169
# Epoch 162/200
# 2/2 [==============================] - 1s 191ms/step - loss: 0.0128 - r_square: 0.7378
# Epoch 163/200
# 2/2 [==============================] - 0s 191ms/step - loss: 0.0132 - r_square: 0.7254
# Epoch 164/200
# 2/2 [==============================] - 0s 195ms/step - loss: 0.0131 - r_square: 0.7357
# Epoch 165/200
# 2/2 [==============================] - 0s 185ms/step - loss: 0.0127 - r_square: 0.7322
# Epoch 166/200
# 2/2 [==============================] - 0s 194ms/step - loss: 0.0129 - r_square: 0.7289
# Epoch 167/200
# 2/2 [==============================] - 0s 189ms/step - loss: 0.0130 - r_square: 0.7239
# Epoch 168/200
# 2/2 [==============================] - 0s 183ms/step - loss: 0.0122 - r_square: 0.7467
# Epoch 169/200
# 2/2 [==============================] - 0s 193ms/step - loss: 0.0130 - r_square: 0.7358
# Epoch 170/200
# 2/2 [==============================] - 0s 205ms/step - loss: 0.0127 - r_square: 0.7452
# Epoch 171/200
# 2/2 [==============================] - 0s 189ms/step - loss: 0.0121 - r_square: 0.7553
# Epoch 172/200
# 2/2 [==============================] - 0s 182ms/step - loss: 0.0120 - r_square: 0.7411
# Epoch 173/200
# 2/2 [==============================] - 0s 198ms/step - loss: 0.0133 - r_square: 0.7231
# Epoch 174/200
# 2/2 [==============================] - 0s 191ms/step - loss: 0.0125 - r_square: 0.7438
# Epoch 175/200
# 2/2 [==============================] - 0s 188ms/step - loss: 0.0126 - r_square: 0.7423
# Epoch 176/200
# 2/2 [==============================] - 0s 177ms/step - loss: 0.0112 - r_square: 0.7626
# Epoch 177/200
# 2/2 [==============================] - 0s 187ms/step - loss: 0.0110 - r_square: 0.7690
# Epoch 178/200
# 2/2 [==============================] - 0s 186ms/step - loss: 0.0115 - r_square: 0.7612
# Epoch 179/200
# 2/2 [==============================] - 0s 191ms/step - loss: 0.0121 - r_square: 0.7536
# Epoch 180/200
# 2/2 [==============================] - 0s 188ms/step - loss: 0.0123 - r_square: 0.7502
# Epoch 181/200
# 2/2 [==============================] - 0s 178ms/step - loss: 0.0132 - r_square: 0.7376
# Epoch 182/200
# 2/2 [==============================] - 0s 190ms/step - loss: 0.0128 - r_square: 0.7423
# Epoch 183/200
# 2/2 [==============================] - 0s 168ms/step - loss: 0.0131 - r_square: 0.7472
# Epoch 184/200
# 2/2 [==============================] - 0s 189ms/step - loss: 0.0126 - r_square: 0.7387
# Epoch 185/200
# 2/2 [==============================] - 0s 189ms/step - loss: 0.0112 - r_square: 0.7700
# Epoch 186/200
# 2/2 [==============================] - 0s 197ms/step - loss: 0.0101 - r_square: 0.7838
# Epoch 187/200
# 2/2 [==============================] - 0s 186ms/step - loss: 0.0127 - r_square: 0.7426
# Epoch 188/200
# 2/2 [==============================] - 0s 188ms/step - loss: 0.0115 - r_square: 0.7701
# Epoch 189/200
# 2/2 [==============================] - 0s 181ms/step - loss: 0.0104 - r_square: 0.7878
# Epoch 190/200
# 2/2 [==============================] - 0s 183ms/step - loss: 0.0112 - r_square: 0.7745
# Epoch 191/200
# 2/2 [==============================] - 0s 190ms/step - loss: 0.0105 - r_square: 0.7895
# Epoch 192/200
# 2/2 [==============================] - 0s 170ms/step - loss: 0.0096 - r_square: 0.7991
# Epoch 193/200
# 2/2 [==============================] - 0s 183ms/step - loss: 0.0099 - r_square: 0.7978
# Epoch 194/200
# 2/2 [==============================] - 0s 192ms/step - loss: 0.0095 - r_square: 0.8080
# Epoch 195/200
# 2/2 [==============================] - 0s 192ms/step - loss: 0.0098 - r_square: 0.8067
# Epoch 196/200
# 2/2 [==============================] - 0s 180ms/step - loss: 0.0093 - r_square: 0.8102
# Epoch 197/200
# 2/2 [==============================] - 0s 203ms/step - loss: 0.0086 - r_square: 0.8222
# Epoch 198/200
# 2/2 [==============================] - 0s 189ms/step - loss: 0.0088 - r_square: 0.8169
# Epoch 199/200
# 2/2 [==============================] - 0s 203ms/step - loss: 0.0087 - r_square: 0.8182
# Epoch 200/200
# 2/2 [==============================] - 0s 186ms/step - loss: 0.0077 - r_square: 0.8339
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 52ms/step
# [[2.03488382e-09 4.45629082e+01 3.24592710e-01 2.49844933e+01
#   1.13021612e+01 1.84946246e-02]
#  [1.81569049e-09 2.16307697e+01 3.27537566e-01 1.57070436e+01
#   7.87340069e+00 7.98570067e-02]
#  [1.64093827e-09 1.71331806e+01 3.24408323e-01 1.80951595e+01
#   6.77372694e+00 9.01210010e-02]
#  [1.57395408e-09 1.68976994e+01 2.77694643e-01 1.88240585e+01
#   6.82078695e+00 8.97849575e-02]
#  [2.02679185e-09 1.65247135e+01 1.90869614e-01 2.41832218e+01
#   1.36714783e+01 8.88343602e-02]
#  [1.59499758e-09 5.05495911e+01 2.68822670e-01 4.03683548e+01
#   1.54977541e+01 3.41852978e-02]
#  [2.10184914e-09 4.64447746e+01 3.34978580e-01 3.82051277e+01
#   1.77707634e+01 2.71451641e-02]
#  [2.42752574e-09 5.09747429e+01 2.75546640e-01 3.57503471e+01
#   1.50286655e+01 5.63242426e-03]
#  [2.07039674e-09 5.00043640e+01 2.11283103e-01 4.15537682e+01
#   1.70091209e+01 2.00528894e-02]
#  [1.99953742e-09 4.92819405e+01 2.95375615e-01 3.78352356e+01
#   1.90124760e+01 1.79881714e-02]
#  [2.18099228e-09 5.17023659e+01 3.35900545e-01 2.82919407e+01
#   1.37817068e+01 4.42409219e-04]
ss_4 = [x for x in db[:step_length] if x >= 6 and x <7]
ss_5 = [x for x in db[:step_length] if x >= 7 and x <8]
ss_6 = [x for x in db[:step_length] if x >= 8 and x <9]
ss_7 = [x for x in db[:step_length] if x >= 9 and x <=10]
ss = [len(ss_1),len(ss_2),len(ss_3),len(ss_4),len(ss_5),len(ss_6),len(ss_7)]
ss_layer = []
temp = 0
for i in ss:
    temp = temp + i
    ss_layer.append(temp)

df_f = pd.DataFrame({'d/b':db ,'Elas': elas, 'density': density, 'phi': phi, 'psi': psi, 'v':v, 'c':c})
df_f_i = pd.DataFrame({'d/b':db ,'Elas': new_elas,'density': new_density, 'phi': new_phi, 'psi': new_psi, 'v':new_v, 'c':new_c})

# %%
import matplotlib.pyplot as plt

# Create a list of parameters to plot
parameters = ['Elas', 'density', 'v', 'phi', 'psi', 'c']

# Loop through each parameter and generate a plot
for var in parameters:
    # Create example lists of data
    L1_down = list(df_f[0:ss_layer[0]][var].values)
    L2_down =  list(df_f[ss_layer[0]:ss_layer[1]][var].values)
    L3_down = list(df_f[ss_layer[1]:ss_layer[2]][var].values)
    L4_down = list(df_f[ss_layer[2]:ss_layer[3]][var].values)
    L5_down =  list(df_f[ss_layer[3]:ss_layer[4]][var].values)
    L6_down = list(df_f[ss_layer[4]:ss_layer[5]][var].values)
    L7_down = list(df_f[ss_layer[5]:ss_layer[6]][var].values)
    L7_up =  list(df_f[ss_layer[6]:ss_layer[6]+ss_layer[0]][var].values)
    L6_up = list(df_f[ss_layer[6]+ss_layer[0]:ss_layer[6]+ss_layer[1]][var].values)
    L5_up = list(df_f[ss_layer[6]+ss_layer[1]:ss_layer[6]+ss_layer[2]][var].values)
    L4_up = list(df_f[ss_layer[6]+ss_layer[2]:ss_layer[6]+ss_layer[3]][var].values)
    L3_up = list(df_f[ss_layer[6]+ss_layer[3]:ss_layer[6]+ss_layer[4]][var].values)
    L2_up = list(df_f[ss_layer[6]+ss_layer[4]:ss_layer[6]+ss_layer[5]][var].values)
    L1_up = list(df_f[ss_layer[6]+ss_layer[5]:(ss_layer[6]+ss_layer[6])-1][var].values)

    L1_down_i = list(df_f_i[0:ss_layer[0]][var].values)
    L2_down_i =  list(df_f_i[ss_layer[0]:ss_layer[1]][var].values)
    L3_down_i = list(df_f_i[ss_layer[1]:ss_layer[2]][var].values)
    L4_down_i = list(df_f_i[ss_layer[2]:ss_layer[3]][var].values)
    L5_down_i =  list(df_f_i[ss_layer[3]:ss_layer[4]][var].values)
    L6_down_i = list(df_f_i[ss_layer[4]:ss_layer[5]][var].values)
    L7_down_i = list(df_f_i[ss_layer[5]:ss_layer[6]][var].values)
    L7_up_i =  list(df_f_i[ss_layer[6]:ss_layer[6]+ss_layer[0]][var].values)
    L6_up_i = list(df_f_i[ss_layer[6]+ss_layer[0]:ss_layer[6]+ss_layer[1]][var].values)
    L5_up_i = list(df_f_i[ss_layer[6]+ss_layer[1]:ss_layer[6]+ss_layer[2]][var].values)
    L4_up_i = list(df_f_i[ss_layer[6]+ss_layer[2]:ss_layer[6]+ss_layer[3]][var].values)
    L3_up_i = list(df_f_i[ss_layer[6]+ss_layer[3]:ss_layer[6]+ss_layer[4]][var].values)
    L2_up_i = list(df_f_i[ss_layer[6]+ss_layer[4]:ss_layer[6]+ss_layer[5]][var].values)
    L1_up_i = list(df_f_i[ss_layer[6]+ss_layer[5]:(ss_layer[6]+ss_layer[6])-1][var].values)
# Combine the data into a list for boxplot function
    data = [L1_down,L2_down,L3_down, L4_down, L5_down,L6_down, L7_down, L7_up, L6_up, L5_up, L4_up, L3_up, L2_up, L1_up, L1_down_i,L2_down_i,L3_down_i, L4_down_i, L5_down,L6_down_i, L7_down_i, L7_up_i, L6_up, L5_up_i, L4_up_i, L3_up_i, L2_up_i, L1_up_i]

    # Generate the boxplot
    # Generate the boxplot
    import matplotlib.pyplot as plt

    fig, axs = plt.subplots(figsize=(12, 4))

    col = ['blue','red']
    layer_colors = []
    for i in range(28):
        if i<14:
            layer_colors.append(col[0])
        else:
            layer_colors.append(col[1])

    # Create a legend for the plot

    # Generate the boxplot with custom box colors
    bp = axs.boxplot(data, boxprops=dict(facecolor='white', color='black', linewidth=2.5), patch_artist=True)

    for patch, color in zip(bp['boxes'], layer_colors):
        patch.set_facecolor(color)

    #axs.set_xticklabels(layers)
    axs.set_title(var)

    plt.show()

# %%
model1 = load_model(ANN1,custom_objects={'RSquare' : tfa.metrics.RSquare})
scaler = pd.read_pickle('scale_ann1.pkl')
ANN1_prediction = ANN1_Predict(model1,scaler,db[k],new_density[k],new_elas[k],new_v[k],new_phi[k],new_psi[k],new_c[k])
ANN1_prediction = np.reshape(ANN1_prediction,-1)
def output_ANN1(ANN1_prediction,df_y1_5):
    a1 = ANN1_prediction
    df_out  = df_y1_5.dropna()
    df_out.insert(3,"ML",a1)
    df_y1_5 = df_y1_5.drop('S-S22', axis =1)
    df_out = df_out.drop('S-S22', axis =1)
    df_out_final = df_y1_5.merge(df_out, how = 'outer')
    #df_out_final = df_out_final.fillna(0)
    return df_out_final
ANN1_Post = output_ANN1(ANN1_prediction,df_y1_5= pd.read_csv('cord.csv'))
from scipy.interpolate import griddata
import numpy as np
import matplotlib.pyplot as plt
x = ANN1_Post['x'].values
y = ANN1_Post['y'].values
z = ANN1_Post['ML'].values
xi = np.linspace(np.min(x), np.max(x), len(x))
yi = np.linspace(np.min(y), np.max(y), len(y))
X,Y= np.meshgrid(xi,yi)
Z = griddata((x, y), z, (X, Y),method='nearest')
#plt.contourf(X,Y,Z)

plt.contourf(X, Y, Z)
plt.title("ML predicted Simulation")
plt.colorbar()
# Out:
# WARNING:tensorflow:6 out of the last 205 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001D291A49EE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 64ms/step

# %%
model1 = load_model(ANN1,custom_objects={'RSquare' : tfa.metrics.RSquare})
scaler = pd.read_pickle('scale_ann1.pkl')
ANN1_prediction = ANN1_Predict(model1,scaler,db[k],density[k],elas[k],v[k],phi[k],psi[k],c[k])
ANN1_prediction = np.reshape(ANN1_prediction,-1)
def output_ANN1(ANN1_prediction,df_y1_5):
    a1 = ANN1_prediction
    df_out  = df_y1_5.dropna()
    df_out.insert(3,"ML",a1)
    df_y1_5 = df_y1_5.drop('S-S22', axis =1)
    df_out = df_out.drop('S-S22', axis =1)
    df_out_final = df_y1_5.merge(df_out, how = 'outer')
    #df_out_final = df_out_final.fillna(0)
    return df_out_final
ANN1_Post = output_ANN1(ANN1_prediction,df_y1_5= pd.read_csv('cord.csv'))
from scipy.interpolate import griddata
import numpy as np
import matplotlib.pyplot as plt
x = ANN1_Post['x'].values
y = ANN1_Post['y'].values
z = ANN1_Post['ML'].values
xi = np.linspace(np.min(x), np.max(x), len(x))
yi = np.linspace(np.min(y), np.max(y), len(y))
X,Y= np.meshgrid(xi,yi)
Z = griddata((x, y), z, (X, Y),method='nearest')
# plt.contourf(X,Y,Z)
# vin = -0.14
# vmax = 0.0
plt.contourf(X, Y, Z)
plt.title("ML predicted Simulation")
plt.colorbar()
# Out:
# 1/1 [==============================] - 0s 62ms/step

# %%
k = 41

df_comp = pd.DataFrame({'d/b':{'Actual':db[k],'Predicted Path':db[k]},'Density':{'Actual':density[k],'Predicted Path':new_density[k]}, 'Elastic Modulus':{'Actual':elas[k],'Predicted Path':new_elas[k]},'V':{'Actual':v[k],'Predicted Path':new_v[k]},'Phi':{'Actual':phi[k],'Predicted Path':new_phi[k]},'Psi':{'Actual':psi[k],'Predicted Path':new_psi[k]},'C':{'Actual':c[k],'Predicted Path':new_c[k]}})
df_comp
# Out:
#                     d/b       Density  Elastic Modulus         V        Phi  \
# Actual          5.89899  2.554214e-09        50.094210  0.374023  24.781124
# Predicted Path  5.89899  1.961362e-09        63.229725  0.318098  30.411705
#
#                       Psi         C
# Actual          13.815754  0.017987
# Predicted Path  13.729024  0.010647

# %%
db
# Out:
# [3.0,
#  3.0707070707070705,
#  3.1414141414141414,
#  3.212121212121212,
#  3.282828282828283,
#  3.3535353535353534,
#  3.4242424242424243,
#  3.494949494949495,
#  3.5656565656565657,
#  3.6363636363636362,
#  3.707070707070707,
#  3.7777777777777777,
#  3.8484848484848486,
#  3.919191919191919,
#  3.9898989898989896,
#  4.0606060606060606,
#  4.1313131313131315,
#  4.202020202020202,
#  4.2727272727272725,
#  4.343434343434343,
#  4.414141414141414,
#  4.484848484848484,
#  4.555555555555555,
#  4.626262626262626,
#  4.696969696969697,
#  4.767676767676767,
#  4.838383838383838,
#  4.909090909090909,
#  4.979797979797979,
#  5.05050505050505,
#  5.121212121212121,
#  5.191919191919192,
#  5.262626262626263,
#  5.333333333333333,
#  5.404040404040404,
#  5.474747474747474,
#  5.545454545454545,
#  5.616161616161616,
#  5.686868686868687,
#  5.757575757575758,
#  5.828282828282829,
#  5.898989898989899,
#  5.96969696969697,
#  6.04040404040404,
#  6.111111111111111,
#  6.181818181818182,
#  6.252525252525253,
#  6.3232323232323235,
#  6.393939393939394,
#  6.4646464646464645,
#  6.535353535353535,
#  6.6060606060606055,
#  6.6767676767676765,
#  6.747474747474747,
#  6.818181818181818,
#  6.888888888888889,
#  6.959595959595959,
#  7.03030303030303,
#  7.101010101010101,
#  7.171717171717171,
#  7.242424242424242,
#  7.313131313131313,
#  7.383838383838384,
#  7.454545454545454,
#  7.525252525252525,
#  7.595959595959596,
#  7.666666666666666,
#  7.737373737373737,
#  7.808080808080808,
#  7.878787878787879,
#  7.949494949494949,
#  8.02020202020202,
#  8.09090909090909,
#  8.161616161616163,
#  8.232323232323232,
#  8.303030303030303,
#  8.373737373737374,
#  8.444444444444445,
#  8.515151515151516,
#  8.585858585858585,
#  8.656565656565657,
#  8.727272727272727,
#  8.797979797979798,
#  8.868686868686869,
#  8.93939393939394,
#  9.01010101010101,
#  9.08080808080808,
#  9.151515151515152,
#  9.222222222222221,
#  9.292929292929292,
#  9.363636363636363,
#  9.434343434343434,
#  9.505050505050505,
#  9.575757575757574,
#  9.646464646464647,
#  9.717171717171716,
#  9.787878787878787,
#  9.858585858585858,
#  9.929292929292929,
#  10.0,
#  10.0,
#  9.929292929292929,
#  9.858585858585858,
#  9.787878787878787,
#  9.717171717171718,
#  9.646464646464647,
#  9.575757575757576,
#  9.505050505050505,
#  9.434343434343434,
#  9.363636363636363,
#  9.292929292929292,
#  9.222222222222221,
#  9.151515151515152,
#  9.080808080808081,
#  9.01010101010101,
#  8.93939393939394,
#  8.868686868686869,
#  8.797979797979798,
#  8.727272727272727,
#  8.656565656565657,
#  8.585858585858587,
#  8.515151515151516,
#  8.444444444444445,
#  8.373737373737374,
#  8.303030303030303,
#  8.232323232323232,
#  8.161616161616163,
#  8.090909090909092,
#  8.02020202020202,
#  7.94949494949495,
#  7.878787878787879,
#  7.808080808080808,
#  7.737373737373737,
#  7.666666666666667,
#  7.595959595959596,
#  7.525252525252526,
#  7.454545454545455,
#  7.383838383838384,
#  7.313131313131313,
#  7.242424242424242,
#  7.171717171717171,
#  7.101010101010101,
#  7.03030303030303,
#  6.95959595959596,
#  6.888888888888889,
#  6.818181818181818,
#  6.747474747474747,
#  6.6767676767676765,
#  6.606060606060606,
#  6.5353535353535355,
#  6.464646464646465,
#  6.3939393939393945,
#  6.3232323232323235,
#  6.252525252525253,
#  6.181818181818182,
#  6.111111111111111,
#  6.040404040404041,
#  5.96969696969697,
#  5.898989898989899,
#  5.828282828282829,
#  5.757575757575758,
#  5.686868686868687,
#  5.616161616161616,
#  5.545454545454546,
#  5.474747474747475,
#  5.404040404040404,
#  5.333333333333334,
#  5.262626262626263,
#  5.191919191919192,
#  5.121212121212121,
#  5.050505050505051,
#  4.97979797979798,
#  4.909090909090909,
#  4.838383838383838,
#  4.767676767676768,
#  4.696969696969697,
#  4.626262626262626,
#  4.555555555555555,
#  4.484848484848485,
#  4.414141414141414,
#  4.343434343434343,
#  4.272727272727273,
#  4.202020202020202,
#  4.1313131313131315,
#  4.0606060606060606,
#  3.9898989898989905,
#  3.9191919191919196,
#  3.8484848484848486,
#  3.7777777777777777,
#  3.7070707070707076,
#  3.6363636363636367,
#  3.5656565656565657,
#  3.494949494949495,
#  3.4242424242424248,
#  3.353535353535354,
#  3.282828282828283,
#  3.212121212121213,
#  3.141414141414142,
#  3.070707070707071,
#  3.0]
