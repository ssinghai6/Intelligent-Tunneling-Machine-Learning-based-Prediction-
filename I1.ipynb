# %%
step_length = 40
interval = 6
iters = 25
main_db = []
main_density = []
main_v = []
main_phi = []
main_psi = []
main_c = []
main_elas = []
#predict_db.append(db)
predict_density = []
predict_v = []
predict_elas = []
predict_phi = []
predict_psi = [] 
predict_c = []
for j in range (0,iters):
    # step_length = 40
    #def data_ses (step_length):
    ## step_length : The number of points between d/b 3 to 10
    from flask import Flask, request, render_template
    from keras.models import load_model
    # import tensorflow_addons as tfa
    import numpy as np
    import sklearn as sk
    import pandas as pd
    from scipy.interpolate import griddata
    import matplotlib.pyplot as plt
    half = step_length
    import numpy as np
    depth = []
    depth[0:half] = np.linspace(3,10,half)
    depth[half:2*half] = np.linspace(10,3,half)
    no = len(depth)
    list_Elas = []
    list_density = []
    list_v =[]
    list_phi = []
    list_psi =[]
    list_c =[]
    
    elas_mus = [50, 20, 55, 50, 40, 30, 60]
    elas_sigmas = [8, 6, 5, 3.5, 3, 2, 1]
    
    density_mus = [2.0e-09,1.80e-09,2.2e-09, 1.90e-09,1.75e-09,2.1e-09,1.6e-09]
    density_sigmas = [0.3e-09, 0.25e-09, 0.2e-09, 0.17e-09, 0.15e-09, 0.11e-09, 0.1e-09]
    
    v_mus = [0.24,0.28,0.35,0.3,0.23,0.36,0.25]
    v_sigmas = [0.07,0.05,0.04,0.03,0.025,0.022,0.02]
    
    phi_mus = [40,20,27,32,35,28,33]
    phi_sigmas = [4,3.5,3,2.5,2,1.5,1]
    
    psi_mus = [20,10,13.5,16,17.5,14,11]
    psi_sigmas = [6,4,3,2.5,2,1.5,1]
    
    c_mus = [0.015,0.08,0.018,0.055,0.085,0.05,0.019]
    c_sigmas = [0.006,0.004,0.003,0.0025,0.002,0.0015,0.001]
    
    
    for d_b in depth:
        if d_b >=3 and d_b<4:
            k = 0 
            mu_density,mu_elas,mu_v,mu_phi,mu_psi,mu_c = density_mus[k],elas_mus[k],v_mus[k],phi_mus[k],psi_mus[k],c_mus[k]
            sigma_density, sigma_elas, sigma_v, sigma_phi, sigma_psi, sigma_c = density_sigmas[k],elas_sigmas[k],v_sigmas[k],phi_sigmas[k],psi_sigmas[k],c_sigmas[k]
            
        if d_b >=4 and d_b<5:
            k = 1
            mu_density,mu_elas,mu_v,mu_phi,mu_psi,mu_c = density_mus[k],elas_mus[k],v_mus[k],phi_mus[k],psi_mus[k],c_mus[k]
            sigma_density, sigma_elas, sigma_v, sigma_phi, sigma_psi, sigma_c = density_sigmas[k],elas_sigmas[k],v_sigmas[k],phi_sigmas[k],psi_sigmas[k],c_sigmas[k]
        if d_b >=5 and d_b<6:
            k = 2 
            mu_density,mu_elas,mu_v,mu_phi,mu_psi,mu_c = density_mus[k],elas_mus[k],v_mus[k],phi_mus[k],psi_mus[k],c_mus[k]
            sigma_density, sigma_elas, sigma_v, sigma_phi, sigma_psi, sigma_c = density_sigmas[k],elas_sigmas[k],v_sigmas[k],phi_sigmas[k],psi_sigmas[k],c_sigmas[k]
        if d_b >=6 and d_b<7:
            k = 3 
            mu_density,mu_elas,mu_v,mu_phi,mu_psi,mu_c = density_mus[k],elas_mus[k],v_mus[k],phi_mus[k],psi_mus[k],c_mus[k]
            sigma_density, sigma_elas, sigma_v, sigma_phi, sigma_psi, sigma_c = density_sigmas[k],elas_sigmas[k],v_sigmas[k],phi_sigmas[k],psi_sigmas[k],c_sigmas[k]
            
        if d_b >=7 and d_b<8:
            k = 4 
            mu_density,mu_elas,mu_v,mu_phi,mu_psi,mu_c = density_mus[k],elas_mus[k],v_mus[k],phi_mus[k],psi_mus[k],c_mus[k]
            sigma_density, sigma_elas, sigma_v, sigma_phi, sigma_psi, sigma_c = density_sigmas[k],elas_sigmas[k],v_sigmas[k],phi_sigmas[k],psi_sigmas[k],c_sigmas[k]
            
        if d_b >=8 and d_b<9:
            k = 5
            mu_density,mu_elas,mu_v,mu_phi,mu_psi,mu_c = density_mus[k],elas_mus[k],v_mus[k],phi_mus[k],psi_mus[k],c_mus[k]
            sigma_density, sigma_elas, sigma_v, sigma_phi, sigma_psi, sigma_c = density_sigmas[k],elas_sigmas[k],v_sigmas[k],phi_sigmas[k],psi_sigmas[k],c_sigmas[k]
            
        if d_b >=9 and d_b<10:
            k = 6 
            mu_density,mu_elas,mu_v,mu_phi,mu_psi,mu_c = density_mus[k],elas_mus[k],v_mus[k],phi_mus[k],psi_mus[k],c_mus[k]
            sigma_density, sigma_elas, sigma_v, sigma_phi, sigma_psi, sigma_c = density_sigmas[k],elas_sigmas[k],v_sigmas[k],phi_sigmas[k],psi_sigmas[k],c_sigmas[k]
                
        list_Elas.append(np.random.normal(mu_elas, sigma_elas))
        list_density.append(np.random.normal(mu_density, sigma_density))
        list_v.append(np.random.normal(mu_v, sigma_v))
        list_phi.append(np.random.normal(mu_phi, sigma_phi))
        list_psi.append(np.random.normal(mu_psi, sigma_psi))
        list_c.append(np.random.normal(mu_c, sigma_c))
    # interval = 3
    from flask import Flask, request, render_template
    from keras.models import load_model
    import tensorflow as tf
    # import tensorflow_addons as tfa
    import numpy as np
    import sklearn as sk
    import pandas as pd
    from scipy.interpolate import griddata
    import matplotlib.pyplot as plt
    import numpy as np
    d_b_list = depth
    E_list = list_Elas
    density_list = list_density
    v_list = list_v
    phi_list = list_phi
    psi_list = list_psi
    c_list = list_c
    no = len(depth)
    batch = 32
    result = []
    para = []
    paras = []
    for i in range(no):
        #d_b,density,E,v,phi,psi,c = d_b_list[i],np.random.choice(density_list),E_list[i],np.random.choice(v_list),np.random.choice(phi_list),np.random.choice(psi_list),np.random.choice(c_list)
        d_b,density,E,v,phi,psi,c = depth[i],density_list[i],E_list[i],v_list[i],phi_list[i],psi_list[i],c_list[i]
        temp1 = [density,E,v,phi,psi,c]
        temp = [d_b,density,E,v,phi,psi,c]
        paras.append(temp1)
        para.append(temp)
        # res_temp = ANN1_Predict(model1,scaler,d_b,density,E,v,phi,psi,c)
        # result.append(res_temp)
    import numpy as np
    import matplotlib.pyplot as plt
    
    
    # Create x-axis values
    x = np.arange(no)
    para1 = np.reshape(para,(no,7))
    # Generate some random y values
    para_d_b = para1[:,0]
    para_density = para1[:,1]
    para_elastic = para1[:,2]
    para_v = para1[:,3]
    para_phi = para1[:,4]
    para_psi = para1[:,5]
    para_c = para1[:,6]
    
    # Create a figure with three subplots
    fig, axs = plt.subplots(nrows=7, ncols=1, figsize=(8, 8))
    
    # Plot each line in a separate subplot
    axs[0].plot(x,para_d_b )
    axs[0].set_title('d_b')
    axs[1].plot(x, para_density)
    axs[1].set_title('Density')
    axs[2].plot(x, para_elastic)
    axs[2].set_title('Elastic Modulus')
    axs[3].plot(x, para_v)
    axs[3].set_title('v')
    axs[4].plot(x, para_phi)
    axs[4].set_title('phi')
    axs[5].plot(x, para_psi)
    axs[5].set_title('psi')
    axs[6].plot(x, para_c)
    axs[6].set_title('c')
    
    # Add x and y axis labels
    for ax in axs:
        ax.set_xlabel('Time Step')
        ax.set_ylabel('Properties')
    
    # Add some space between the subplots
    fig.tight_layout()
    
    # Display the plot
    plt.show()
    
    import numpy as np
    from keras.models import Sequential
    from keras.layers import Dense, LSTM, GRU
    from sklearn.preprocessing import MinMaxScaler
    # import tensorflow_addons as tfa
    
    # Define the number of input parameters and time steps
    num_inputs = 6
    time_steps = interval
    # Generate some random data for demonstration purposes
    data = paras
    
    # Normalize the data
    scaler = MinMaxScaler()
    data = scaler.fit_transform(data)
    
    # Create the training data using a sliding window approach
    X_train = []
    y_train = []
    for i in range(time_steps, len(data)):
        X_train.append(data[i-time_steps:i, :])
        y_train.append(data[i, :])
    
    X_train = np.array(X_train)
    y_train = np.array(y_train)
    
    # Reshape the input data to be 3-dimensional in the form (samples, time steps, features)
    X_train = np.reshape(X_train, (X_train.shape[0], time_steps, num_inputs))
    
    # Define the LSTM model
    model = Sequential()
    model.add(GRU(512, input_shape=(time_steps, num_inputs), return_sequences=True))
    model.add(GRU(300, activation="relu", return_sequences=True))
    model.add(GRU(200, activation="relu"))
    model.add(Dense(num_inputs))
    metric = tf.keras.metrics.R2Score()
    model.compile(optimizer='adam', loss='mse', metrics=[metric], run_eagerly=True)
    
    # Train the model
    model.fit(X_train, y_train, epochs=200, batch_size= batch)
    
    # Generate predictions for the next n time steps
    n = no*2
    last_steps = data[-time_steps:, :]
    predictions = []
    for i in range(n):
        next_step = model.predict(last_steps.reshape(1, time_steps, num_inputs))
        predictions.append(next_step)
        last_steps = np.concatenate((last_steps[1:], next_step), axis=0)
    
    # Reshape predictions to be 2-dimensional in the form (time steps, features)
    predictions = np.array(predictions).reshape(n, num_inputs)
    
    # Inverse transform the predictions back to the original scale
    predictions = scaler.inverse_transform(predictions)
    
    # Print the predictions
    print(predictions)
    
    new_db =[]
    new_elas = []
    new_density = []
    new_v = []
    new_phi = []
    new_psi =[]
    new_c = []
    for i in range(n):
        # new_db.append(predictions[i][0])
        new_density.append(predictions[i][0])
        new_elas.append(predictions[i][1])
        new_v.append(predictions[i][2])
        new_phi.append(predictions[i][3])
        new_psi.append(predictions[i][4])
        new_c.append(predictions[i][5])
    db =[]
    elas= []
    v = []
    phi = []
    psi = []
    c = []
    density = []
    for i in range(no):
        db.append(para[i][0])
        density.append(para[i][1])
        elas.append(para[i][2])
        v.append(para[i][3])
        phi.append(para[i][4])
        psi.append(para[i][5])
        c.append(para[i][6])
    main_db.append(db)
    main_elas.append(elas)
    main_density.append(density)
    main_v.append(v)
    main_phi.append(phi)
    main_psi.append(psi)
    main_c.append(c)
    #predict_db.append(db)
    predict_density.append(new_density)
    predict_elas.append(new_elas)
    predict_v.append(new_v)
    predict_phi.append(new_phi)
    predict_psi.append(new_psi)
    predict_c.append(new_c)
# Out:
# Epoch 1/200
# /Users/sanshritsinghai/venv-metal/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.2881 - r2_score: -4.0526
# Epoch 2/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0974 - r2_score: -0.7515
# Epoch 3/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0724 - r2_score: -0.2223
# Epoch 4/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0761 - r2_score: -0.3560
# Epoch 5/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0650 - r2_score: -0.0870
# Epoch 6/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0607 - r2_score: -0.0679
# Epoch 7/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0560 - r2_score: 0.0165
# Epoch 8/200
# ...

# %%
list1= {'main_db' : main_db, 'main_density':main_density, 'main_v' : main_v,
'main_phi' :main_phi ,'main_psi': main_psi,'main_c' : main_c, 'main_elas': main_elas,
'predict_density':predict_density ,'predict_v' : predict_v ,'predict_elas':predict_elas, 'predict_phi': predict_phi,
'predict_psi':predict_psi, 'predict_c' :predict_c}

# %%
ss_1 = [x for x in db[:step_length] if x >= 3 and x <4]
ss_2 = [x for x in db[:step_length] if x >= 4 and x <5]
ss_3 = [x for x in db[:step_length] if x >= 5 and x <6]
ss_4 = [x for x in db[:step_length] if x >= 6 and x <7]
ss_5 = [x for x in db[:step_length] if x >= 7 and x <8]
ss_6 = [x for x in db[:step_length] if x >= 8 and x <9]
ss_7 = [x for x in db[:step_length] if x >= 9 and x <=10]
ss = [len(ss_1),len(ss_2),len(ss_3),len(ss_4),len(ss_5),len(ss_6),len(ss_7)]
ss_layer = []
temp = 0
for i in ss:
    temp = temp + i
    ss_layer.append(temp)

# %%
# Initialize lists for each attribute
l1_mu_density, l2_mu_density, l3_mu_density, l4_mu_density, l5_mu_density, l6_mu_density, l7_mu_density = [], [], [], [], [], [], []
l1_mu_density_p, l2_mu_density_p, l3_mu_density_p, l4_mu_density_p, l5_mu_density_p, l6_mu_density_p, l7_mu_density_p = [], [], [], [], [], [], []

l1_mu_v, l2_mu_v, l3_mu_v, l4_mu_v, l5_mu_v, l6_mu_v, l7_mu_v = [], [], [], [], [], [], []
l1_mu_v_p, l2_mu_v_p, l3_mu_v_p, l4_mu_v_p, l5_mu_v_p, l6_mu_v_p, l7_mu_v_p = [], [], [], [], [], [], []

l1_mu_phi, l2_mu_phi, l3_mu_phi, l4_mu_phi, l5_mu_phi, l6_mu_phi, l7_mu_phi = [], [], [], [], [], [], []
l1_mu_phi_p, l2_mu_phi_p, l3_mu_phi_p, l4_mu_phi_p, l5_mu_phi_p, l6_mu_phi_p, l7_mu_phi_p = [], [], [], [], [], [], []

l1_mu_psi, l2_mu_psi, l3_mu_psi, l4_mu_psi, l5_mu_psi, l6_mu_psi, l7_mu_psi = [], [], [], [], [], [], []
l1_mu_psi_p, l2_mu_psi_p, l3_mu_psi_p, l4_mu_psi_p, l5_mu_psi_p, l6_mu_psi_p, l7_mu_psi_p = [], [], [], [], [], [], []

l1_mu_c, l2_mu_c, l3_mu_c, l4_mu_c, l5_mu_c, l6_mu_c, l7_mu_c = [], [], [], [], [], [], []
l1_mu_c_p, l2_mu_c_p, l3_mu_c_p, l4_mu_c_p, l5_mu_c_p, l6_mu_c_p, l7_mu_c_p = [], [], [], [], [], [], []

# Calculate de based on ss as before
de = []
v = 0
for j in range(0, len(ss)):
    v = v + ss[j]
    de.append(v)

# Loop through iterations and calculate means for each attribute
for i in range(0, iters):
    # For main_density and predict_density
    l1_mu_density.append(np.mean(main_density[i][0:de[0]]))
    l1_mu_density_p.append(np.mean(predict_density[i][0:de[0]]))
    l2_mu_density.append(np.mean(main_density[i][de[0]:de[1]]))
    l2_mu_density_p.append(np.mean(predict_density[i][de[0]:de[1]]))
    l3_mu_density.append(np.mean(main_density[i][de[1]:de[2]]))
    l3_mu_density_p.append(np.mean(predict_density[i][de[1]:de[2]]))
    l4_mu_density.append(np.mean(main_density[i][de[2]:de[3]]))
    l4_mu_density_p.append(np.mean(predict_density[i][de[2]:de[3]]))
    l5_mu_density.append(np.mean(main_density[i][de[3]:de[4]]))
    l5_mu_density_p.append(np.mean(predict_density[i][de[3]:de[4]]))
    l6_mu_density.append(np.mean(main_density[i][de[4]:de[5]]))
    l6_mu_density_p.append(np.mean(predict_density[i][de[4]:de[5]]))
    l7_mu_density.append(np.mean(main_density[i][de[5]:de[6]]))
    l7_mu_density_p.append(np.mean(predict_density[i][de[5]:de[6]]))

    # For main_v and predict_v
    l1_mu_v.append(np.mean(main_v[i][0:de[0]]))
    l1_mu_v_p.append(np.mean(predict_v[i][0:de[0]]))
    l2_mu_v.append(np.mean(main_v[i][de[0]:de[1]]))
    l2_mu_v_p.append(np.mean(predict_v[i][de[0]:de[1]]))
    l3_mu_v.append(np.mean(main_v[i][de[1]:de[2]]))
    l3_mu_v_p.append(np.mean(predict_v[i][de[1]:de[2]]))
    l4_mu_v.append(np.mean(main_v[i][de[2]:de[3]]))
    l4_mu_v_p.append(np.mean(predict_v[i][de[2]:de[3]]))
    l5_mu_v.append(np.mean(main_v[i][de[3]:de[4]]))
    l5_mu_v_p.append(np.mean(predict_v[i][de[3]:de[4]]))
    l6_mu_v.append(np.mean(main_v[i][de[4]:de[5]]))
    l6_mu_v_p.append(np.mean(predict_v[i][de[4]:de[5]]))
    l7_mu_v.append(np.mean(main_v[i][de[5]:de[6]]))
    l7_mu_v_p.append(np.mean(predict_v[i][de[5]:de[6]]))

    # For main_phi and predict_phi
    l1_mu_phi.append(np.mean(main_phi[i][0:de[0]]))
    l1_mu_phi_p.append(np.mean(predict_phi[i][0:de[0]]))
    l2_mu_phi.append(np.mean(main_phi[i][de[0]:de[1]]))
    l2_mu_phi_p.append(np.mean(predict_phi[i][de[0]:de[1]]))
    l3_mu_phi.append(np.mean(main_phi[i][de[1]:de[2]]))
    l3_mu_phi_p.append(np.mean(predict_phi[i][de[1]:de[2]]))
    l4_mu_phi.append(np.mean(main_phi[i][de[2]:de[3]]))
    l4_mu_phi_p.append(np.mean(predict_phi[i][de[2]:de[3]]))
    l5_mu_phi.append(np.mean(main_phi[i][de[3]:de[4]]))
    l5_mu_phi_p.append(np.mean(predict_phi[i][de[3]:de[4]]))
    l6_mu_phi.append(np.mean(main_phi[i][de[4]:de[5]]))
    l6_mu_phi_p.append(np.mean(predict_phi[i][de[4]:de[5]]))
    l7_mu_phi.append(np.mean(main_phi[i][de[5]:de[6]]))
    l7_mu_phi_p.append(np.mean(predict_phi[i][de[5]:de[6]]))

    # For main_psi and predict_psi
    l1_mu_psi.append(np.mean(main_psi[i][0:de[0]]))
    l1_mu_psi_p.append(np.mean(predict_psi[i][0:de[0]]))
    l2_mu_psi.append(np.mean(main_psi[i][de[0]:de[1]]))
    l2_mu_psi_p.append(np.mean(predict_psi[i][de[0]:de[1]]))
    l3_mu_psi.append(np.mean(main_psi[i][de[1]:de[2]]))
    l3_mu_psi_p.append(np.mean(predict_psi[i][de[1]:de[2]]))
    l4_mu_psi.append(np.mean(main_psi[i][de[2]:de[3]]))
    l4_mu_psi_p.append(np.mean(predict_psi[i][de[2]:de[3]]))
    l5_mu_psi.append(np.mean(main_psi[i][de[3]:de[4]]))
    l5_mu_psi_p.append(np.mean(predict_psi[i][de[3]:de[4]]))
    l6_mu_psi.append(np.mean(main_psi[i][de[4]:de[5]]))
    l6_mu_psi_p.append(np.mean(predict_psi[i][de[4]:de[5]]))
    l7_mu_psi.append(np.mean(main_psi[i][de[5]:de[6]]))
    l7_mu_psi_p.append(np.mean(predict_psi[i][de[5]:de[6]]))

    # For main_c and predict_c
    l1_mu_c.append(np.mean(main_c[i][0:de[0]]))
    l1_mu_c_p.append(np.mean(predict_c[i][0:de[0]]))
    l2_mu_c.append(np.mean(main_c[i][de[0]:de[1]]))
    l2_mu_c_p.append(np.mean(predict_c[i][de[0]:de[1]]))
    l3_mu_c.append(np.mean(main_c[i][de[1]:de[2]]))
    l3_mu_c_p.append(np.mean(predict_c[i][de[1]:de[2]]))
    l4_mu_c.append(np.mean(main_c[i][de[2]:de[3]]))
    l4_mu_c_p.append(np.mean(predict_c[i][de[2]:de[3]]))
    l5_mu_c.append(np.mean(main_c[i][de[3]:de[4]]))
    l5_mu_c_p.append(np.mean(predict_c[i][de[3]:de[4]]))
    l6_mu_c.append(np.mean(main_c[i][de[4]:de[5]]))
    l6_mu_c_p.append(np.mean(predict_c[i][de[4]:de[5]]))
    l7_mu_c.append(np.mean(main_c[i][de[5]:de[6]]))
    l7_mu_c_p.append(np.mean(predict_c[i][de[5]:de[6]]))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Data for each property
data_elas = [l1_mu_elas, l2_mu_elas, l3_mu_elas, l4_mu_elas, l5_mu_elas, l6_mu_elas, l7_mu_elas,
             l1_mu_elas_p, l2_mu_elas_p, l3_mu_elas_p, l4_mu_elas_p, l5_mu_elas_p, l6_mu_elas_p, l7_mu_elas_p]
data_density = [l1_mu_density, l2_mu_density, l3_mu_density, l4_mu_density, l5_mu_density, l6_mu_density, l7_mu_density,
                l1_mu_density_p, l2_mu_density_p, l3_mu_density_p, l4_mu_density_p, l5_mu_density_p, l6_mu_density_p, l7_mu_density_p]
data_v = [l1_mu_v, l2_mu_v, l3_mu_v, l4_mu_v, l5_mu_v, l6_mu_v, l7_mu_v,
          l1_mu_v_p, l2_mu_v_p, l3_mu_v_p, l4_mu_v_p, l5_mu_v_p, l6_mu_v_p, l7_mu_v_p]
data_phi = [l1_mu_phi, l2_mu_phi, l3_mu_phi, l4_mu_phi, l5_mu_phi, l6_mu_phi, l7_mu_phi,
            l1_mu_phi_p, l2_mu_phi_p, l3_mu_phi_p, l4_mu_phi_p, l5_mu_phi_p, l6_mu_phi_p, l7_mu_phi_p]
data_psi = [l1_mu_psi, l2_mu_psi, l3_mu_psi, l4_mu_psi, l5_mu_psi, l6_mu_psi, l7_mu_psi,
            l1_mu_psi_p, l2_mu_psi_p, l3_mu_psi_p, l4_mu_psi_p, l5_mu_psi_p, l6_mu_psi_p, l7_mu_psi_p]
data_c = [l1_mu_c, l2_mu_c, l3_mu_c, l4_mu_c, l5_mu_c, l6_mu_c, l7_mu_c,
          l1_mu_c_p, l2_mu_c_p, l3_mu_c_p, l4_mu_c_p, l5_mu_c_p, l6_mu_c_p, l7_mu_c_p]

# Labels for the box plots
labels = ['L1', 'L2', 'L3', 'L4', 'L5', 'L6', 'L7',
          'L1\'', 'L2\'', 'L3\'', 'L4\'', 'L5\'', 'L6\'', 'L7\'']

# Colors for the known (red) and predicted (blue) boxes
palette = ['red'] * 7 + ['blue'] * 7

# Create subplots for each property
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.suptitle("Box Plots of Mean Properties Across Layers (Known vs Predicted)")

# Plot each property
sns.boxplot(data=data_elas, palette=palette, ax=axes[0, 0])
axes[0, 0].set_title("Elasticity")
axes[0, 0].set_xticklabels(labels)

sns.boxplot(data=data_density, palette=palette, ax=axes[0, 1])
axes[0, 1].set_title("Density")
axes[0, 1].set_xticklabels(labels)

sns.boxplot(data=data_v, palette=palette, ax=axes[0, 2])
axes[0, 2].set_title("Velocity")
axes[0, 2].set_xticklabels(labels)

sns.boxplot(data=data_phi, palette=palette, ax=axes[1, 0])
axes[1, 0].set_title("Phi")
axes[1, 0].set_xticklabels(labels)

sns.boxplot(data=data_psi, palette=palette, ax=axes[1, 1])
axes[1, 1].set_title("Psi")
axes[1, 1].set_xticklabels(labels)

sns.boxplot(data=data_c, palette=palette, ax=axes[1, 2])
axes[1, 2].set_title("C")
axes[1, 2].set_xticklabels(labels)

# Adding a single legend for all plots
red_patch = plt.Line2D([0], [0], color='red', label='Known')
blue_patch = plt.Line2D([0], [0], color='blue', label='Predicted')
fig.legend(handles=[red_patch, blue_patch], loc='upper right')

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
# Out:
# /var/folders/4l/rrftr6v57ls6nj164pgr3w800000gn/T/ipykernel_15968/736714120.py:33: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0, 0].set_xticklabels(labels)
# /var/folders/4l/rrftr6v57ls6nj164pgr3w800000gn/T/ipykernel_15968/736714120.py:37: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0, 1].set_xticklabels(labels)
# /var/folders/4l/rrftr6v57ls6nj164pgr3w800000gn/T/ipykernel_15968/736714120.py:41: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0, 2].set_xticklabels(labels)
# /var/folders/4l/rrftr6v57ls6nj164pgr3w800000gn/T/ipykernel_15968/736714120.py:45: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Calculate mean values for each property
data_elas_mean = [np.mean(l1_mu_elas), np.mean(l2_mu_elas), np.mean(l3_mu_elas), np.mean(l4_mu_elas), 
                  np.mean(l5_mu_elas), np.mean(l6_mu_elas), np.mean(l7_mu_elas),
                  np.mean(l1_mu_elas_p), np.mean(l2_mu_elas_p), np.mean(l3_mu_elas_p), np.mean(l4_mu_elas_p), 
                  np.mean(l5_mu_elas_p), np.mean(l6_mu_elas_p), np.mean(l7_mu_elas_p)]

data_density_mean = [np.mean(l1_mu_density), np.mean(l2_mu_density), np.mean(l3_mu_density), np.mean(l4_mu_density), 
                     np.mean(l5_mu_density), np.mean(l6_mu_density), np.mean(l7_mu_density),
                     np.mean(l1_mu_density_p), np.mean(l2_mu_density_p), np.mean(l3_mu_density_p), np.mean(l4_mu_density_p), 
                     np.mean(l5_mu_density_p), np.mean(l6_mu_density_p), np.mean(l7_mu_density_p)]

data_v_mean = [np.mean(l1_mu_v), np.mean(l2_mu_v), np.mean(l3_mu_v), np.mean(l4_mu_v), 
               np.mean(l5_mu_v), np.mean(l6_mu_v), np.mean(l7_mu_v),
               np.mean(l1_mu_v_p), np.mean(l2_mu_v_p), np.mean(l3_mu_v_p), np.mean(l4_mu_v_p), 
               np.mean(l5_mu_v_p), np.mean(l6_mu_v_p), np.mean(l7_mu_v_p)]

data_phi_mean = [np.mean(l1_mu_phi), np.mean(l2_mu_phi), np.mean(l3_mu_phi), np.mean(l4_mu_phi), 
                 np.mean(l5_mu_phi), np.mean(l6_mu_phi), np.mean(l7_mu_phi),
                 np.mean(l1_mu_phi_p), np.mean(l2_mu_phi_p), np.mean(l3_mu_phi_p), np.mean(l4_mu_phi_p), 
                 np.mean(l5_mu_phi_p), np.mean(l6_mu_phi_p), np.mean(l7_mu_phi_p)]

data_psi_mean = [np.mean(l1_mu_psi), np.mean(l2_mu_psi), np.mean(l3_mu_psi), np.mean(l4_mu_psi), 
                 np.mean(l5_mu_psi), np.mean(l6_mu_psi), np.mean(l7_mu_psi),
                 np.mean(l1_mu_psi_p), np.mean(l2_mu_psi_p), np.mean(l3_mu_psi_p), np.mean(l4_mu_psi_p), 
                 np.mean(l5_mu_psi_p), np.mean(l6_mu_psi_p), np.mean(l7_mu_psi_p)]

data_c_mean = [np.mean(l1_mu_c), np.mean(l2_mu_c), np.mean(l3_mu_c), np.mean(l4_mu_c), 
               np.mean(l5_mu_c), np.mean(l6_mu_c), np.mean(l7_mu_c),
               np.mean(l1_mu_c_p), np.mean(l2_mu_c_p), np.mean(l3_mu_c_p), np.mean(l4_mu_c_p), 
               np.mean(l5_mu_c_p), np.mean(l6_mu_c_p), np.mean(l7_mu_c_p)]

# Labels for the plots
labels = ['L1', 'L2', 'L3', 'L4', 'L5', 'L6', 'L7',
          'L1\'', 'L2\'', 'L3\'', 'L4\'', 'L5\'', 'L6\'', 'L7\'']

# Colors for the known (red) and predicted (blue) lines
known_color = 'red'
predicted_color = 'blue'

# Create subplots for each property
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.suptitle("Mean Properties Across Layers (Known vs Predicted)")

# Define a function to plot mean values as line plots
def plot_line(ax, means, title):
    # Extract known and predicted data
    known_means = means[:7]
    predicted_means = means[7:]

    # Plot known data
    ax.plot(range(7), known_means, color=known_color, marker='o', linestyle='-', label='Known')
    # Plot predicted data
    ax.plot(range(7, 14), predicted_means, color=predicted_color, marker='x', linestyle='--', label='Predicted')

    ax.set_xticks(range(14))
    ax.set_xticklabels(labels, rotation=45)
    ax.set_xlabel("Layers")
    ax.set_ylabel("Mean Value")
    ax.set_title(title)
    ax.legend()

# Plot each property
plot_line(axes[0, 0], data_elas_mean, "Elasticity")
plot_line(axes[0, 1], data_density_mean, "Density")
plot_line(axes[0, 2], data_v_mean, "Velocity")
plot_line(axes[1, 0], data_phi_mean, "Phi")
plot_line(axes[1, 1], data_psi_mean, "Psi")
plot_line(axes[1, 2], data_c_mean, "C")

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
