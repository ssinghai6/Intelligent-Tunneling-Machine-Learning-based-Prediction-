# %%
import pandas as pd
import numpy as np
import os
sim = 998
nodes = 9271
c = []
t = []
for i in range(1,sim+1):
    file = f'csv_files/sim_w_comb_{i}/S_U_PEEQ_COORD_{i}.csv'
    if os.path.isfile(file):
        df_c = pd.read_csv(file)
        c.append(df_c)
        df_t = pd.read_csv(f"csv_files/sim_w_comb_{i}/sim_w_comb_{i}.txt")
        t.append(df_t)

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\ssinghai6\anaconda\lib\site-packages (2.8.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorflow) (1.43.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorflow) (3.19.4)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorflow) (2.8.0.dev2021122109)
# Requirement already satisfied: flatbuffers>=1.12 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorflow) (2.0)
# Requirement already satisfied: gast>=0.2.1 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorflow) (0.24.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: numpy>=1.20 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorflow) (1.20.3)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorflow) (3.2.1)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: setuptools in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorflow) (58.0.4)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorflow) (13.0.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ssinghai6\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (3.3.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.6.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.26.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.0.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\ssinghai6\anaconda\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.4.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ssinghai6\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (5.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ssinghai6\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ssinghai6\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ssinghai6\anaconda\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\ssinghai6\anaconda\lib\site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\ssinghai6\anaconda\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\ssinghai6\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ssinghai6\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ssinghai6\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\ssinghai6\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ssinghai6\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ssinghai6\anaconda\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (3.2.0)

# %%
t_df = pd.concat(t)
c_df = pd.concat(c)
c_df = c_df.replace('       NoValue', np.nan)

# %%
c_df.columns = c_df.columns.str.lstrip()
t_df.columns = t_df.columns.str.lstrip()

# %%
# Output data for the model
y = c_df.iloc[:,16:21]
y = y.astype({'PEEQ': float,'S-S11':float, 'S-S22':float, 'S-S33':float, 'S-S12':float})
df_y = pd.DataFrame({'PEEQ':y.iloc[:,0] ,'S-S11':y.iloc[:,1], 'S-S22':y.iloc[:,2], 'S-S33':y.iloc[:,3], 'S-S12':y.iloc[:,4]})

# %%
#sim  = len(x_d)

# %%
x = t_df.iloc[:,1:]
x_d = x.values
list1 = []
for i in x_d[:,4]:
    i = np.char.replace(i,"]","")
    i = np.char.replace(i," ","")
    i = float(i)
    list1.append(i)
# for j in x_d[:,0]:
#     i = np.char.replace(j,"[","")
#     i = np.char.replace(j," ","")
#     j = float(j)
#     list2.append(i)
x_data = np.zeros((975,5))
x_data[:,0:4] = x_d[:,0:4]
x_data[:,4] = list1
np.shape(x_d)
#x_global = np.zeros(((nodes-1)*sim,5))
x_global = np.zeros((9037275,5))
for i in range(975):
    x_global[(nodes)*i:(nodes)*(i+1),:] = x_data[i,:] 
df_x = pd.DataFrame({'E':x_global[:,0], 'mu':x_global[:,1],'phi':x_global[:,2],'psi':x_global[:,3], 'c':x_global[:,4], 'x':c_df.iloc[:,5],'y':c_df.iloc[:,6]})

# %%
#df_x

# %%
df_global = pd.concat([df_x, df_y], axis=1)

# %%
df_global
# Out:
#           E   mu   phi   psi       c        x         y  PEEQ     S-S11  \
# 0      30.0  0.2  20.0   2.0  0.0131 -2500.00  2500.000   NaN -0.024198
# 1      30.0  0.2  20.0   2.0  0.0131 -2500.00     0.000   NaN -0.053829
# 2      30.0  0.2  20.0   2.0  0.0131 -2500.00 -2500.000   NaN -0.076216
# 3      30.0  0.2  20.0   2.0  0.0131     0.00  2500.000   NaN -0.028770
# 4      30.0  0.2  20.0   2.0  0.0131     0.00 -2500.000   NaN -0.082632
# ...     ...  ...   ...   ...     ...      ...       ...   ...       ...
# 9264  100.0  0.4  45.0  40.5  0.0377  2137.56  -473.618   0.0 -0.040826
# 9265  100.0  0.4  45.0  40.5  0.0377  2048.66  -909.661   0.0 -0.040301
# 9266  100.0  0.4  45.0  40.5  0.0377  2129.95  -927.103   0.0 -0.040568
# 9267  100.0  0.4  45.0  40.5  0.0377  2131.49  -770.993   0.0 -0.040585
# 9268  100.0  0.4  45.0  40.5  0.0377  2170.72  -629.206   0.0 -0.040785
#
#          S-S22     S-S33     S-S12
# 0    -0.041168 -0.025720 -0.002831
# 1    -0.084719 -0.053438 -0.000252
# 2    -0.120091 -0.077969  0.002362
# 3    -0.030920 -0.024307 -0.000161
# 4    -0.107417 -0.076870 -0.000174
# ...        ...       ...       ...
# 9264 -0.133715 -0.040915  0.001648
# 9265 -0.144563 -0.042742  0.001127
# 9266 -0.144578 -0.042763  0.001158
# 9267 -0.140971 -0.042151  0.001543
# 9268 -0.137374 -0.041541  0.001649
#
# [9037275 rows x 12 columns]

# %%
# df_global.drop(df_global[df_global['S-S11'] == 0].index, inplace = True)
# df_global.drop(df_global[df_global['S-S22'] == 0].index, inplace = True)
# df_global.drop(df_global[df_global['S-S33'] == 0].index, inplace = True)
# df_global.drop(df_global[df_global['S-S12'] == 0].index, inplace = True)
df_global = df_global.fillna({'PEEQ': 0})
df_global = df_global.dropna()

# %%
df_global_x = df_global.iloc[:,0:7]

# %%
df_global_x.to_csv('Data_x.csv')

# %%
df_global.to_csv('Data.csv')

# %%
df_global.iloc[:,7:13]
# Out:
#       PEEQ     S-S11     S-S22     S-S33     S-S12
# 0      0.0 -0.024198 -0.041168 -0.025720 -0.002831
# 1      0.0 -0.053829 -0.084719 -0.053438 -0.000252
# 2      0.0 -0.076216 -0.120091 -0.077969  0.002362
# 3      0.0 -0.028770 -0.030920 -0.024307 -0.000161
# 4      0.0 -0.082632 -0.107417 -0.076870 -0.000174
# ...    ...       ...       ...       ...       ...
# 9264   0.0 -0.040826 -0.133715 -0.040915  0.001648
# 9265   0.0 -0.040301 -0.144563 -0.042742  0.001127
# 9266   0.0 -0.040568 -0.144578 -0.042763  0.001158
# 9267   0.0 -0.040585 -0.140971 -0.042151  0.001543
# 9268   0.0 -0.040785 -0.137374 -0.041541  0.001649
#
# [7638150 rows x 5 columns]

# %%
data_x = df_global.iloc[:,0:7].values
data_y = df_global.iloc[:,7:13].values

# %%
# Spliting test and training
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data_x, data_y, test_size=0.05, random_state = 42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SSINGH~1\AppData\Local\Temp/ipykernel_186464/4277383893.py in <module>
#       1 # Spliting test and training
#       2 from sklearn.model_selection import train_test_split
# ----> 3 x_train, x_test, y_train, y_test = train_test_split(data_x, data_y, test_size=0.05, random_state = 42)
#       4 t_train
#
# NameError: name 'data_x' is not defined

# %%
#Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
import tensorflow as tf
print(tf.__version__)
# Part 2:Building an ANN using keras
#Initializing ANN
ann = tf.keras.models.Sequential()
# Out:
# 2.8.0

# %%
#Adding the input and first hidden layer, will be adding a dense layer
ann.add(tf.keras.layers.Dense(units = 15,activation = tf.keras.layers.LeakyReLU(alpha=0.01)))

# %%
#Adding second hidden layer
ann.add(tf.keras.layers.Dense(units = 13, activation = tf.keras.layers.LeakyReLU(alpha=0.01)))
#ann.add(tf.keras.layers.Dense(units = 12, activation = tf.keras.layers.LeakyReLU(alpha=0.01)))
#ann.add(tf.keras.layers.Dense(units = 20, activation = 'relu'))
#ann.add(tf.keras.layers.Dense(units = 20, activation = 'relu'))
ann.add(tf.keras.layers.Dense(units = 8, activation = tf.keras.layers.LeakyReLU(alpha=0.01)))
ann.add(tf.keras.layers.Dense(units = 8, activation = tf.keras.layers.LeakyReLU(alpha=0.01)))

# %%
#Output Layer
ann.add(tf.keras.layers.Dense(units = 5, activation = 'linear'))

# %%
#compling ann
ann.compile(optimizer = 'adam', loss = 'mean_squared_error',metrics = ['accuracy'])

# %%
#traing the model
ann.fit(x_train,y_train,batch_size = 128, epochs = 50)
# Out:
# Epoch 1/50
# 56690/56690 [==============================] - 78s 1ms/step - loss: 4.7051e-04 - accuracy: 0.8043
# Epoch 2/50
# 56690/56690 [==============================] - 76s 1ms/step - loss: 4.1420e-04 - accuracy: 0.8321
# Epoch 3/50
# 56690/56690 [==============================] - 76s 1ms/step - loss: 4.0691e-04 - accuracy: 0.8376
# Epoch 4/50
# 56690/56690 [==============================] - 77s 1ms/step - loss: 4.0223e-04 - accuracy: 0.8379
# Epoch 5/50
# 56690/56690 [==============================] - 77s 1ms/step - loss: 3.9848e-04 - accuracy: 0.8314
# Epoch 6/50
# 56690/56690 [==============================] - 77s 1ms/step - loss: 3.9536e-04 - accuracy: 0.8296
# Epoch 7/50
# 56690/56690 [==============================] - 79s 1ms/step - loss: 3.9246e-04 - accuracy: 0.8315
# Epoch 8/50
# 56690/56690 [==============================] - 78s 1ms/step - loss: 3.9084e-04 - accuracy: 0.8341
# Epoch 9/50
# 56690/56690 [==============================] - 77s 1ms/step - loss: 3.8925e-04 - accuracy: 0.8382
# Epoch 10/50
# 56690/56690 [==============================] - 75s 1ms/step - loss: 3.8863e-04 - accuracy: 0.8404
# Epoch 11/50
# 56690/56690 [==============================] - 77s 1ms/step - loss: 3.8761e-04 - accuracy: 0.8412
# Epoch 12/50
# 56690/56690 [==============================] - 78s 1ms/step - loss: 3.8712e-04 - accuracy: 0.8427
# Epoch 13/50
# 56690/56690 [==============================] - 79s 1ms/step - loss: 3.8660e-04 - accuracy: 0.8440
# Epoch 14/50
# 56690/56690 [==============================] - 79s 1ms/step - loss: 3.8622e-04 - accuracy: 0.8438
# Epoch 15/50
# 56690/56690 [==============================] - 78s 1ms/step - loss: 3.8573e-04 - accuracy: 0.8434
# Epoch 16/50
# 56690/56690 [==============================] - 77s 1ms/step - loss: 3.8535e-04 - accuracy: 0.8423
# Epoch 17/50
# 56690/56690 [==============================] - 78s 1ms/step - loss: 3.8521e-04 - accuracy: 0.8411
# Epoch 18/50
# 56690/56690 [==============================] - 77s 1ms/step - loss: 3.8459e-04 - accuracy: 0.8396
# Epoch 19/50
# 56690/56690 [==============================] - 78s 1ms/step - loss: 3.8423e-04 - accuracy: 0.8386
# Epoch 20/50
# 56690/56690 [==============================] - 78s 1ms/step - loss: 3.8409e-04 - accuracy: 0.8395
# Epoch 21/50
# 56690/56690 [==============================] - 78s 1ms/step - loss: 3.8335e-04 - accuracy: 0.8392
# Epoch 22/50
# 56690/56690 [==============================] - 78s 1ms/step - loss: 3.8263e-04 - accuracy: 0.8388
# Epoch 23/50
# 56690/56690 [==============================] - 78s 1ms/step - loss: 3.8173e-04 - accuracy: 0.8393
# Epoch 24/50
# 56690/56690 [==============================] - 78s 1ms/step - loss: 3.8068e-04 - accuracy: 0.8394
# Epoch 25/50
# 56690/56690 [==============================] - 78s 1ms/step - loss: 3.7966e-04 - accuracy: 0.8393
# Epoch 26/50
# 56690/56690 [==============================] - 80s 1ms/step - loss: 3.7958e-04 - accuracy: 0.8404
# Epoch 27/50
# 56690/56690 [==============================] - 80s 1ms/step - loss: 3.7848e-04 - accuracy: 0.8445
# Epoch 28/50
# 56690/56690 [==============================] - 80s 1ms/step - loss: 3.7791e-04 - accuracy: 0.8443
# Epoch 29/50
# 56690/56690 [==============================] - 80s 1ms/step - loss: 3.7817e-04 - accuracy: 0.8440
# Epoch 30/50
# 56690/56690 [==============================] - 80s 1ms/step - loss: 3.7719e-04 - accuracy: 0.8437
# Epoch 31/50
# 56690/56690 [==============================] - 79s 1ms/step - loss: 3.7663e-04 - accuracy: 0.8487
# Epoch 32/50
# 56690/56690 [==============================] - 79s 1ms/step - loss: 3.7659e-04 - accuracy: 0.8480
# Epoch 33/50
# 56690/56690 [==============================] - 79s 1ms/step - loss: 3.7604e-04 - accuracy: 0.8473
# Epoch 34/50
# 56690/56690 [==============================] - 80s 1ms/step - loss: 3.7558e-04 - accuracy: 0.8472
# Epoch 35/50
# 56690/56690 [==============================] - 80s 1ms/step - loss: 3.7523e-04 - accuracy: 0.8475
# Epoch 36/50
# 56690/56690 [==============================] - 80s 1ms/step - loss: 3.7547e-04 - accuracy: 0.8466
# Epoch 37/50
# 56690/56690 [==============================] - 80s 1ms/step - loss: 3.7497e-04 - accuracy: 0.8463
# Epoch 38/50
# 56690/56690 [==============================] - 80s 1ms/step - loss: 3.7520e-04 - accuracy: 0.8455
# Epoch 39/50
# 56690/56690 [==============================] - 80s 1ms/step - loss: 3.7502e-04 - accuracy: 0.8458
# Epoch 40/50
# 56690/56690 [==============================] - 80s 1ms/step - loss: 3.7494e-04 - accuracy: 0.8462
# Epoch 41/50
# 56690/56690 [==============================] - 80s 1ms/step - loss: 3.7451e-04 - accuracy: 0.8463
# Epoch 42/50
# 56690/56690 [==============================] - 79s 1ms/step - loss: 3.7477e-04 - accuracy: 0.8462
# Epoch 43/50
# 56690/56690 [==============================] - 79s 1ms/step - loss: 3.7423e-04 - accuracy: 0.8479
# Epoch 44/50
# 56690/56690 [==============================] - 80s 1ms/step - loss: 3.7449e-04 - accuracy: 0.8458
# Epoch 45/50
# 56690/56690 [==============================] - 80s 1ms/step - loss: 3.7344e-04 - accuracy: 0.8465
# Epoch 46/50
# 56690/56690 [==============================] - 80s 1ms/step - loss: 3.7363e-04 - accuracy: 0.8477
# Epoch 47/50
# 56690/56690 [==============================] - 80s 1ms/step - loss: 3.7364e-04 - accuracy: 0.8469
# Epoch 48/50
# 56690/56690 [==============================] - 80s 1ms/step - loss: 3.7376e-04 - accuracy: 0.8471
# Epoch 49/50
# 56690/56690 [==============================] - 80s 1ms/step - loss: 3.7331e-04 - accuracy: 0.8472
# Epoch 50/50
# 56690/56690 [==============================] - 79s 1ms/step - loss: 3.7294e-04 - accuracy: 0.8475

# %%
#a1 = ann.predict(sc.transform([[30,0.4,38.75,19.375,0.005,600,2500]]))

# %%
def get_data(w):
    import pandas as pd
    import numpy as np
    sim = 1
    nodes = 9270
    c = []
    t = []
    #for i in range(1,sim+1):
    
    df_c = pd.read_csv(f'csv_files1/sim_w_comb_{w}/S_U_PEEQ_COORD_{w}.csv')
    c.append(df_c)
    df_t = pd.read_csv(f'csv_files1/sim_w_comb_{w}/sim_w_comb_{w}.txt')
    t.append(df_t)
    t_df = pd.concat(t)
    c_df = pd.concat(c)
    c_df = c_df.replace('       NoValue', np.nan)
    c_df.columns = c_df.columns.str.lstrip()
    t_df.columns = t_df.columns.str.lstrip()
    # Output data for the model
    y = c_df.iloc[:,16:21]
    y = y.astype({'PEEQ': float,'S-S11':float, 'S-S22':float, 'S-S33':float, 'S-S12':float})
    df_y = pd.DataFrame({'PEEQ':y.iloc[:,0] ,'S-S11':y.iloc[:,1], 'S-S22':y.iloc[:,2], 'S-S33':y.iloc[:,3], 'S-S12':y.iloc[:,4]})
    x = t_df.iloc[:,1:]
    x_d = x.values
    list1 = []
    for i in x_d[:,4]:
        i = np.char.replace(i,"]","")
        i = np.char.replace(i," ","")
        i = float(i)
        list1.append(i)
    # for j in x_d[:,0]:
    #     i = np.char.replace(j,"[","")
    #     i = np.char.replace(j," ","")
    #     j = float(j)
    #     list2.append(i)
    x_data = np.zeros((sim,5))
    x_data[:,0:4] = x_d[:,0:4]
    x_data[:,4] = list1
    np.shape(x_d)
    x_global = np.zeros(((nodes-1)*sim,5))
    for i in range(sim):
        x_global[(nodes)*i:(nodes)*(i+1),:] = x_data[i,:] 
    x_input = pd.DataFrame({'E':x_global[:,0], 'mu':x_global[:,1],'phi':x_global[:,2],'psi':x_global[:,3], 'c':x_global[:,4], 'x':c_df.iloc[:,5],'y':c_df.iloc[:,6]})
    #x_in = np.zeros((nodes-1,7))
    df_global = pd.concat([x_input, df_y], axis=1)
#     df_global.drop(df_global[df_global['S-S11'] == 0].index, inplace = True)
#     df_global.drop(df_global[df_global['S-S22'] == 0].index, inplace = True)
#     df_global.drop(df_global[df_global['S-S33'] == 0].index, inplace = True)
#     df_global.drop(df_global[df_global['S-S12'] == 0].index, inplace = True)
    #df_global = df_global.fillna({'PEEQ': 0})
    #dd = df_global.dropna()
    #data_x = df_global.iloc[:,0:7].values
    #data_y = df_global.iloc[:,7:13].values
    
#     x_in = np.zeros((nodes-1,7))
#     for i in range(0,7):
#         x_in[:,i] = x_input.T.iloc[i]
    return(df_global)

    #return {'x': data_x, 'y': data_y }
    #return

# %%
output16 = np.zeros((7834,5))
output134 = np.zeros((7834,5))
output198 = np.zeros((7834,5))
output312 = np.zeros((7834,5))
output401 = np.zeros((7834,5))
output632 = np.zeros((7834,5))
output708 = np.zeros((7834,5))
output795 = np.zeros((7834,5))
output866 = np.zeros((7834,5))
output987 = np.zeros((7834,5))
for i in range(0,7834):
    output16[i,:] = ann.predict(sc.transform([get_data(16).fillna({'PEEQ': 0}).dropna().iloc[:,0:7].values.tolist()[i]]))
    output134[i,:] = ann.predict(sc.transform([get_data(134).fillna({'PEEQ': 0}).dropna().iloc[:,0:7].values.tolist()[i]]))
    output198[i,:] = ann.predict(sc.transform([get_data(198).fillna({'PEEQ': 0}).dropna().iloc[:,0:7].values.tolist()[i]]))
    output312[i,:] = ann.predict(sc.transform([get_data(312).fillna({'PEEQ': 0}).dropna().iloc[:,0:7].values.tolist()[i]]))
    output401[i,:] = ann.predict(sc.transform([get_data(401).fillna({'PEEQ': 0}).dropna().iloc[:,0:7].values.tolist()[i]]))
    output632[i,:] = ann.predict(sc.transform([get_data(632).fillna({'PEEQ': 0}).dropna().iloc[:,0:7].values.tolist()[i]]))
    output708[i,:] = ann.predict(sc.transform([get_data(708).fillna({'PEEQ': 0}).dropna().iloc[:,0:7].values.tolist()[i]]))
    output795[i,:] = ann.predict(sc.transform([get_data(795).fillna({'PEEQ': 0}).dropna().iloc[:,0:7].values.tolist()[i]]))
    output866[i,:] = ann.predict(sc.transform([get_data(866).fillna({'PEEQ': 0}).dropna().iloc[:,0:7].values.tolist()[i]]))
    output987[i,:] = ann.predict(sc.transform([get_data(987).fillna({'PEEQ': 0}).dropna().iloc[:,0:7].values.tolist()[i]]))

# %%
j = [16,134,198,312,401,632,708,795,866,987]
df_global = get_data(j[9]).fillna({'PEEQ': 0})
dd = df_global.dropna()
data_x1 = df_global.replace(np.nan,0).iloc[:,0:7].values
data_y1 = df_global.replace(np.nan,0).iloc[:,7:13].values
data_X1 = df_global.iloc[:,0:7].values
data_Y1 = df_global.iloc[:,7:13].values
data_x = dd.iloc[:,0:7].values
data_y = dd.iloc[:,7:13].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SSINGH~1\AppData\Local\Temp/ipykernel_84148/4181671478.py in <module>
#       1 j = [16,134,198,312,401,632,708,795,866,987]
# ----> 2 df_global = get_data(j[9]).fillna({'PEEQ': 0})
#       3 dd = df_global.dropna()
#       4 data_x1 = df_global.replace(np.nan,0).iloc[:,0:7].values
#       5 data_y1 = df_global.replace(np.nan,0).iloc[:,7:13].values
#
# NameError: name 'get_data' is not defined

# %%
Z = data_y1.tolist()
cord = data_x1.tolist()
s = []
s_out = []
x_cor = []
y_cor = []
error = []
sigma = 1
# sigma = 1(sxx); sigma =2 (syy) ; sigma = 3 (szz)
for i in range(9269):
    temp1 = Z[:][i][sigma]
    s.append(temp1)
    temp2 = cord[:][i][5]
    x_cor.append(temp2)
    temp3 = cord[:][i][6]
    y_cor.append(temp3)
for i in range(7834):
    temp4 = output16[:][i][sigma]
    s_out.append(temp4)
#     e = (abs(s_out[i]-s[i])*100)/abs(s[i])
#     error.append(e)

# %%
import pandas as pd
ddi = pd.DataFrame({'x':data_X1[:,5],'y': data_X1[:,6],'s11' : data_Y1[:,1]})
ddf = pd.DataFrame({'x':data_x[:,5], 'y':data_x[:,6], 's11': s_out})
#d_ml = pd.merge(ddi,ddf, how ='inner', on = 'x')
#ddi.isnull().sum()
ddf2 = ddi[ddi['s11'].isna()]
df_ml = pd.concat([ddf,ddf2])
df_ml = df_ml.replace(np.nan,0)
x1_ml = df_ml['x'].tolist()
y1_ml = df_ml['y'].tolist()
s11_out = df_ml['s11'].tolist()

# %%
from scipy.interpolate import griddata
import numpy as np
import matplotlib.pyplot as plt

x = np.asarray(x_cor)
y = np.asarray(y_cor)
z = np.asarray(s)
xi = np.linspace(np.min(x), np.max(x), len(x))
yi = np.linspace(np.min(y), np.max(y), len(y))

X,Y= np.meshgrid(xi,yi)
Z = griddata((x, y), z, (X, Y),method='nearest')
plt.contourf(X,Y,Z)
plt.title("Abaqus Simulation s11 (sim:401)")
plt.colorbar()

# %%
from scipy.interpolate import griddata
import numpy as np
import matplotlib.pyplot as plt
x = np.asarray(x1_ml)
y = np.asarray(y1_ml)
z = np.asarray(s11_out)
xi = np.linspace(np.min(x), np.max(x), len(x))
yi = np.linspace(np.min(y), np.max(y), len(y))

X,Y= np.meshgrid(xi,yi)
Z = griddata((x, y), z, (X, Y),method='nearest')
plt.contourf(X,Y,Z)
plt.title("ML predicted Simulation s11 (sim:401)")
plt.colorbar()

# %%
z
# Out:
# array([-0.00458162, -0.02191786, -0.02967938, ..., -0.02180192,
#        -0.02167762, -0.02165786])
